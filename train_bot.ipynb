# %% [markdown]
# # Train LSTM

# %%
from google.colab import drive

drive.mount('/gdrive')
drive_path = '/gdrive/My Drive/Github/aux-net'
# %cd '/gdrive/My Drive/Github/aux-net'

from bot_LSTM import aux_bot_LSTM

# Create bot and train
bot_LSTM = aux_bot_LSTM(drive_path = drive_path, pos_path = "/matlab/training/data/2024_02_03_14_22_02/positions_trim_new.csv", motor_path = "/matlab/training/data/2024_02_03_14_22_02/training_waypoints_matrix.mat",
              train_forward=True, train_inverse=False, normalize=True)
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/Github/aux-net
# Connected:  cuda:0
# Loaded positions:  (12498, 7)
# Loaded inputs:  (12498, 9)
# (Epoch 1, Iter 100) loss: 0.000217
# (Epoch 1, Iter 200) loss: 0.000145
# (Epoch 1, Iter 300) loss: 0.000122
# (Epoch 1, Iter 400) loss: 0.000138
# (Epoch 1, Iter 500) loss: 0.000117
# (Epoch 1, Iter 600) loss: 0.000300
# (Epoch 2, Iter 100) loss: 0.000102
# (Epoch 2, Iter 200) loss: 0.000112
# (Epoch 2, Iter 300) loss: 0.000093
# (Epoch 2, Iter 400) loss: 0.000105
# (Epoch 2, Iter 500) loss: 0.000101
# (Epoch 2, Iter 600) loss: 0.000098
# (Epoch 3, Iter 100) loss: 0.000077
# (Epoch 3, Iter 200) loss: 0.000085
# (Epoch 3, Iter 300) loss: 0.000083
# (Epoch 3, Iter 400) loss: 0.000081
# (Epoch 3, Iter 500) loss: 0.000087
# (Epoch 3, Iter 600) loss: 0.000089
# (Epoch 4, Iter 100) loss: 0.000079
# (Epoch 4, Iter 200) loss: 0.000077
# ...

# %% [markdown]
# # Train DNN

# %%
from google.colab import drive

drive.mount('/gdrive')
drive_path = '/gdrive/My Drive/Github/aux-net'
# %cd '/gdrive/My Drive/Github/aux-net'

from bot_DNN import aux_bot_DNN

# Create bot and train
bot_DNN = aux_bot_DNN(drive_path = drive_path, pos_path = "/matlab/training/data/2024_02_03_14_22_02/positions_trim_new.csv", motor_path = "/matlab/training/data/2024_02_03_14_22_02/training_waypoints_matrix.mat",
              train_forward=True, train_inverse=False, normalize=True)

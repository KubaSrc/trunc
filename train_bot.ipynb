# %% [markdown]
# # Train LSTM

# %%
from google.colab import drive

drive.mount('/gdrive')
drive_path = '/gdrive/My Drive/Github/aux-net'
# %cd '/gdrive/My Drive/Github/aux-net'

from bot_LSTM import aux_bot_LSTM

# Create bot and train
bot_LSTM = aux_bot_LSTM(drive_path = drive_path, pos_path = "/matlab/training/data/2024_02_04_11_40_02/positions_full.csv", motor_path = "/matlab/training/data/2024_02_04_11_40_02/training_waypoints_matrix.mat",
              train_forward=False, train_inverse=True, normalize=True)
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Github/aux-net
# Connected:  cuda:0
# Loaded positions:  (40000, 7)
# Loaded inputs:  (40000, 9)
# [aux_bot_LSTM] Forward model succesfully loaded
# (Epoch 1, Iter 100) loss: 0.004371
# (Epoch 1, Iter 200) loss: 0.002976
# (Epoch 1, Iter 300) loss: 0.002708
# (Epoch 1, Iter 400) loss: 0.002741
# (Epoch 1, Iter 500) loss: 0.002373
# (Epoch 1, Iter 600) loss: 0.002367
# (Epoch 1, Iter 700) loss: 0.002476
# (Epoch 1, Iter 800) loss: 0.002180
# (Epoch 1, Iter 900) loss: 0.002270
# (Epoch 1, Iter 1000) loss: 0.002283
# (Epoch 1, Iter 1100) loss: 0.002155
# (Epoch 1, Iter 1200) loss: 0.002399
# (Epoch 1, Iter 1300) loss: 0.002310
# (Epoch 1, Iter 1400) loss: 0.002279
# (Epoch 1, Iter 1500) loss: 0.002112
# (Epoch 1, Iter 1600) loss: 0.002191
# (Epoch 1, Iter 1700) loss: 0.002519
# (Epoch 1, Iter 1800) loss: 0.002276
# (Epoch 1, Iter 1900) loss: 0.002109
# (Epoch 1, Iter 2000) loss: 0.002193
# (Epoch 2, Iter 100) loss: 0.002142
# ...

# %% [markdown]
# # Train DNN

# %%
from google.colab import drive

drive.mount('/gdrive')
drive_path = '/gdrive/My Drive/Github/aux-net'
# %cd '/gdrive/My Drive/Github/aux-net'

from bot_DNN import aux_bot_DNN

# Create bot and train
bot_DNN = aux_bot_DNN(drive_path = drive_path, pos_path = "/matlab/training/data/2024_02_04_11_40_02/positions_full.csv", motor_path = "/matlab/training/data/2024_02_04_11_40_02/training_waypoints_matrix.mat",
              train_forward=False, train_inverse=True, normalize=True)

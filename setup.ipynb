# %% [markdown]
# ## Packages

# %% [markdown]
# ### Export packages

# %%
# !conda env export > environment.yml

# %% [markdown]
# ### Install packages

# %%
# !conda env create -f environment.yml

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
drive_path = '/gdrive/My Drive/Github/aux-net'

# %cd '/gdrive/My Drive/Github/aux-net'
# !git config --global user.email "kubekk101@gmail.com"
# !git config --global user.name "KubaSrc"
# !git config --global core.editor "nano"
# !git config pull.rebase false
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Github/aux-net

# %%
# !git add .
# !git commit -m "New inverse model"

# %%
# !git push
# Out:
# Enumerating objects: 37, done.
# Counting objects: 100% (30/30), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (21/21), done.
# Writing objects: 100% (21/21), 53.25 MiB | 5.54 MiB/s, done.
# Total 21 (delta 10), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (10/10), completed with 6 local objects.
# To https://github.com/KubaSrc/aux-net.git
#    c329a29..665fea0  main -> main

# %%
# !git branch --set-upstream-to=origin/main main
# !git pull
# Out:
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 18 (delta 12), reused 18 (delta 12), pack-reused 0
# Unpacking objects: 100% (18/18), 114.48 KiB | 97.00 KiB/s, done.
# From https://github.com/KubaSrc/aux-net
#    9a4c6be..36ef6f7  main       -> origin/main
# Updating 9a4c6be..36ef6f7
# Fast-forward
#  __pycache__/bot.cpython-311.pyc                                 | Bin 33967 -> 34480 bytes
#  __pycache__/bot_LSTM.cpython-311.pyc                            | Bin 10701 -> 10694 bytes
#  bot.py                                                          |  33 ++-
#  bot_LSTM.py                                                     |   2 +-
#  figures/repetability/random.emf                                 | Bin 0 -> 515624 bytes
#  figures/repetability/trajectory.emf                             | Bin 0 -> 512192 bytes
#  .../repetability_analysis.m => repetability_analysis.asv}       |  24 +-
#  matlab/repetability_analysis.m                                  | 427 +++++-----------------------
#  matlab/training/follow_trajectory.asv                           |  99 -------
#  matlab/training/generate_trajectory.asv                         | 232 ++++++++-------
#  matlab/training/generate_trajectory.m                           |  51 +++-
#  matlab/training/repetability_analysis.asv                       | 127 ---------
#  matlab/training/trajectory_analysis.asv                         |  18 --
#  matlab/training/trajectory_sweep.asv                            | 113 --------
#  matlab/training/trunc_model.asv                                 | 259 -----------------
#  matlab/{training => }/trajectory_analysis.m                     |   0
#  matlab/{training => }/workspace_analysis.m                      |   0
#  run_bot.ipynb                                                   |   2 +-
#  18 files changed, 285 insertions(+), 1102 deletions(-)
#  create mode 100644 figures/repetability/random.emf
#  create mode 100644 figures/repetability/trajectory.emf
#  rename matlab/{training/repetability_analysis.m => repetability_analysis.asv} (84%)
#  delete mode 100644 matlab/training/follow_trajectory.asv
#  delete mode 100644 matlab/training/repetability_analysis.asv
#  delete mode 100644 matlab/training/trajectory_analysis.asv
#  delete mode 100644 matlab/training/trajectory_sweep.asv
#  delete mode 100644 matlab/training/trunc_model.asv
#  rename matlab/{training => }/trajectory_analysis.m (100%)
#  rename matlab/{training => }/workspace_analysis.m (100%)

# %%
# !git merge --no-edit
# Out:
# Already up to date.

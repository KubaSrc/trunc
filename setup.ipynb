# %% [markdown]
# ## Packages

# %% [markdown]
# ### Export packages

# %%
# !conda env export > environment.yml

# %% [markdown]
# ### Install packages

# %%
# !conda env create -f environment.yml

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
drive_path = '/gdrive/My Drive/Github/aux-net'

# %cd '/gdrive/My Drive/Github/aux-net'
# !git config --global user.email "kubekk101@gmail.com"
# !git config --global user.name "KubaSrc"
# !git config --global core.editor "nano"
# !git config pull.rebase false
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/Github/aux-net

# %%
# !git add .
# !git commit -m "New inverse model"
# Out:
# [main c6dfa76] New inverse model
#  13 files changed, 197 insertions(+), 197 deletions(-)
#  create mode 100644 metrics/LSTM_inverse_2024_02_06-15_26_44_10.485mm
#  create mode 100644 metrics/LSTM_inverse_2024_02_06-17_45_21_10.445mm
#  create mode 100644 metrics/LSTM_inverse_2024_02_06-18_17_58_11.218mm
#  create mode 100644 metrics/LSTM_inverse_2024_02_06-19_24_47_10.454mm
#  create mode 100644 models/LSTM_inverse_2024_02_06-15_26_44_10.485mm
#  create mode 100644 models/LSTM_inverse_2024_02_06-17_45_21_10.445mm
#  create mode 100644 models/LSTM_inverse_2024_02_06-18_17_58_11.218mm
#  create mode 100644 models/LSTM_inverse_2024_02_06-19_24_47_10.454mm
#  rewrite setup.ipynb (78%)
#  rewrite train_bot.ipynb (95%)

# %%
# !git push
# Out:
# To https://github.com/KubaSrc/aux-net.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/KubaSrc/aux-net.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git branch --set-upstream-to=origin/main main
# !git pull
# Out:
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# error: You have not concluded your merge (MERGE_HEAD exists).
# hint: Please, commit your changes before merging.
# fatal: Exiting because of unfinished merge.

# %%
# !git merge --no-edit

# %% [markdown]
# ## Packages

# %% [markdown]
# ### Export packages

# %%
# !conda env export > environment.yml

# %% [markdown]
# ### Install packages

# %%
# !conda env create -f environment.yml

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
drive_path = '/gdrive/My Drive/Github/aux-net'

# %cd '/gdrive/My Drive/Github/aux-net'
# !git config --global user.email "kubekk101@gmail.com"
# !git config --global user.name "KubaSrc"
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Github/aux-net

# %%
# !git add .
# !git commit -m "New inverse model"

# %%
# !git push
# Out:
# Enumerating objects: 29, done.
# Counting objects: 100% (29/29), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (20/20), done.
# Writing objects: 100% (20/20), 49.86 MiB | 5.38 MiB/s, done.
# Total 20 (delta 8), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (8/8), completed with 6 local objects.
# To https://github.com/KubaSrc/aux-net.git
#    018fffe..866ea6a  main -> main

# %%
# !git branch --set-upstream-to=origin/main main
# !git pull
# Out:
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 8 (delta 6), reused 8 (delta 6), pack-reused 0
# Unpacking objects: 100% (8/8), 2.57 MiB | 2.51 MiB/s, done.
# From https://github.com/KubaSrc/aux-net
#    8fb6716..7790165  main       -> origin/main
# Updating 8fb6716..7790165
# Fast-forward
#  matlab/training/data/2024_02_04_11_40_02/training_waypoints_matrix.mat | Bin 0 -> 2691634 bytes
#  matlab/training/reshape_trajectory.m                                   |   4 ++--
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  create mode 100644 matlab/training/data/2024_02_04_11_40_02/training_waypoints_matrix.mat

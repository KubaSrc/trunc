# %% [markdown]
# ## Packages

# %% [markdown]
# ### Export packages

# %%
# !conda env export > environment.yml

# %% [markdown]
# ### Install packages

# %%
# !conda env create --name trunc -f environment.yml
# Out:
# Channels:
#  - pytorch
#  - nvidia
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working... Ran pip subprocess with arguments:
# ['C:\\Users\\Big Strong 2.0\\anaconda3\\envs\\trunc\\python.exe', '-m', 'pip', 'install', '-U', '-r', 'c:\\Users\\Big Strong 2.0\\Documents\\GitHub\\trunc\\condaenv.d9m71_dl.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Collecting torchaudio==2.2.0 (from -r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 1))
#
#   Downloading torchaudio-2.2.0-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
#
# Collecting torchvision==0.17.0 (from -r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 2))
#
#   Downloading torchvision-0.17.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
#
# Requirement already satisfied: torch==2.2.0 in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from torchaudio==2.2.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 1)) (2.2.0)
#
# Requirement already satisfied: numpy in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from torchvision==0.17.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 2)) (1.26.3)
#
# Requirement already satisfied: requests in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from torchvision==0.17.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 2)) (2.31.0)
#
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from torchvision==0.17.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 2)) (10.0.1)
#
# Requirement already satisfied: filelock in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from torch==2.2.0->torchaudio==2.2.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 1)) (3.13.1)
#
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from torch==2.2.0->torchaudio==2.2.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 1)) (4.9.0)
#
# Requirement already satisfied: sympy in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from torch==2.2.0->torchaudio==2.2.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 1)) (1.12)
#
# Requirement already satisfied: networkx in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from torch==2.2.0->torchaudio==2.2.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 1)) (3.1)
#
# Requirement already satisfied: jinja2 in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from torch==2.2.0->torchaudio==2.2.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 1)) (3.1.3)
#
# Collecting fsspec (from torch==2.2.0->torchaudio==2.2.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 1))
#
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
#
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from requests->torchvision==0.17.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 2)) (2.0.4)
#
# Requirement already satisfied: idna<4,>=2.5 in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from requests->torchvision==0.17.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 2)) (3.4)
#
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from requests->torchvision==0.17.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 2)) (1.26.18)
#
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from requests->torchvision==0.17.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 2)) (2023.11.17)
#
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from jinja2->torch==2.2.0->torchaudio==2.2.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 1)) (2.1.3)
#
# Requirement already satisfied: mpmath>=0.19 in c:\users\big strong 2.0\anaconda3\envs\trunc\lib\site-packages (from sympy->torch==2.2.0->torchaudio==2.2.0->-r c:\Users\Big Strong 2.0\Documents\GitHub\trunc\condaenv.d9m71_dl.requirements.txt (line 1)) (1.3.0)
#
# Downloading torchaudio-2.2.0-cp311-cp311-win_amd64.whl (2.4 MB)
#
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.4 MB 5.6 MB/s eta 0:00:01
#    ------------- -------------------------- 0.8/2.4 MB 12.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.0/2.4 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.4 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 15.1 MB/s eta 0:00:00
#
# Downloading torchvision-0.17.0-cp311-cp311-win_amd64.whl (1.2 MB)
#
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 37.3 MB/s eta 0:00:00
#
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
#
#    ---------------------------------------- 0.0/179.6 kB ? eta -:--:--
#    ---------------------------------------- 179.6/179.6 kB ? eta 0:00:00
#
# Installing collected packages: fsspec, torchvision, torchaudio
#
# Successfully installed fsspec-2024.10.0 torchaudio-2.2.0 torchvision-0.17.0
#
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate trunc
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
# C:\Users\Big Strong 2.0\anaconda3\Lib\argparse.py:2006: FutureWarning: `remote_definition` is deprecated and will be removed in 25.9. Use `conda env create --file=URL` instead.
#   action(self, namespace, argument_values, option_string)
# WARNING: A space was detected in your requested environment path:
# 'C:\Users\Big Strong 2.0\anaconda3\envs\trunc'
# Spaces in paths can sometimes be problematic. To minimize issues,
# make sure you activate your environment before running any executables!

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
drive_path = '/gdrive/My Drive/Github/aux-net'

# %cd '/gdrive/My Drive/Github/aux-net'
# !git config --global user.email "kubekk101@gmail.com"
# !git config --global user.name "KubaSrc"
# !git config --global core.editor "nano"
# !git config pull.rebase false
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Github/aux-net

# %%
# !git status
# Out:
# ^C

# %%
# !git add .
# !git commit -m "Inverse models for LSTM and DNN"
# Out:
# ^C
# ^C

# %%
# !git push
# Out:
# To https://github.com/KubaSrc/aux-net.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/KubaSrc/aux-net.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git branch --set-upstream-to=origin/main main
# !git pull
# Out:
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 19 (delta 11), reused 19 (delta 11), pack-reused 0
# Unpacking objects: 100% (19/19), 8.28 KiB | 1024 bytes/s, done.
# From https://github.com/KubaSrc/aux-net
#    7b5129e..a9a126f  main       -> origin/main
# hint: Waiting for your editor to close the file... error: cannot run nano: No such file or directory
# error: unable to start editor 'nano'
# Not committing merge; use 'git commit' to complete the merge.

# %%
# !git merge --no-edit
# Out:
# fatal: You have not concluded your merge (MERGE_HEAD exists).
# Please, commit your changes before you merge.

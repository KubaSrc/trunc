# %% [markdown]
# ## Packages

# %% [markdown]
# ### Export packages

# %%
# !conda env export > environment.yml

# %% [markdown]
# ### Install packages

# %%
# !conda env create -f environment.yml

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
drive_path = '/gdrive/My Drive/Github/aux-net'

# %cd '/gdrive/My Drive/Github/aux-net'
# !git config --global user.email "kubekk101@gmail.com"
# !git config --global user.name "KubaSrc"
# !git config --global core.editor "nano"
# !git config pull.rebase false
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Github/aux-net

# %%
# !git add .
# !git commit -m "New inverse model"
# Out:
# [main d85365a] New inverse model
#  10 files changed, 2 insertions(+), 2 deletions(-)
#  create mode 100644 metrics/LSTM_forward_2024_02_15-14_58_09_2.992mm
#  create mode 100644 metrics/LSTM_inverse_2024_02_15-14_37_57_8.007mm
#  create mode 100644 metrics/LSTM_inverse_2024_02_15-14_50_17_10.288mm
#  create mode 100644 models/LSTM_forward_2024_02_15-14_58_09_2.992mm
#  create mode 100644 models/LSTM_inverse_2024_02_15-14_37_57_8.007mm
#  create mode 100644 models/LSTM_inverse_2024_02_15-14_50_17_10.288mm
#  rewrite setup.ipynb (86%)
#  rewrite train_bot.ipynb (96%)

# %%
# !git push
# Out:
# Enumerating objects: 22, done.
# Counting objects: 100% (22/22), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (15/15), done.
# Writing objects: 100% (15/15), 41.06 MiB | 9.10 MiB/s, done.
# Total 15 (delta 6), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (6/6), completed with 5 local objects.
# To https://github.com/KubaSrc/aux-net.git
#    36ef6f7..d85365a  main -> main

# %%
# !git branch --set-upstream-to=origin/main main
# !git pull
# Out:
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 21 (delta 17), reused 15 (delta 11), pack-reused 0
# Unpacking objects: 100% (21/21), 1.51 MiB | 263.00 KiB/s, done.
# From https://github.com/KubaSrc/aux-net
#    581fef0..7b5129e  main       -> origin/main
# Updating 581fef0..7b5129e
# Fast-forward
#  matlab/training/data/2024_02_19_21_08_57/positions.csv          | 3200 +++++++++++++++++++++++
#  matlab/training/data/2024_02_19_21_08_57/positions_norm.csv     | 3704 +++++++++++++++++++++++++--
#  .../training/data/2024_02_19_21_08_57/positions_norm_full.csv   | 3704 +++++++++++++++++++++++++--
#  3 files changed, 10104 insertions(+), 504 deletions(-)

# %%
# !git merge --no-edit
# Out:
# Already up to date.

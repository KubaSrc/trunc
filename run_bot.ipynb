# %% [markdown]
# # LSTM Bot

# %%
from bot_LSTM import aux_bot_LSTM

# Create bot and train
bot_LSTM = aux_bot_LSTM(drive_path = './', pos_path = "/matlab/training/data/2024_02_03_14_22_02/positions_trim_new.csv", motor_path = "/matlab/training/data/2024_02_03_14_22_02/training_waypoints_matrix.mat",
              train_forward=False, train_inverse=False, normalize=True)
# Out:
# Connected:  cuda:0
# Loaded positions:  (12498, 7)
# Loaded inputs:  (12498, 9)
# [aux_bot_LSTM] Forward model succesfully loaded
# [aux_bot_LSTM] Inverse model succesfully loaded

# %%
bot_LSTM.inverse_prediction('matlab/testing/circle_trajectory.mat','matlab/testing/circle_trajectory_inputs.mat')
# Out:
# [aux_bot] Running model inference.
# (100, 7)
# (100, 9)
# tensor([[ 0.4810,  0.4925,  0.0146,  0.9999, -0.0038,  0.0123,  0.0081],
#         [ 0.5015,  0.4783,  0.0215,  0.9999, -0.0038,  0.0123,  0.0081],
#         [ 0.5201,  0.4671,  0.0276,  0.9999, -0.0038,  0.0123,  0.0081],
#         [ 0.5367,  0.4586,  0.0330,  0.9999, -0.0038,  0.0123,  0.0081],
#         [ 0.5514,  0.4528,  0.0376,  0.9999, -0.0038,  0.0123,  0.0081],
#         [ 0.5643,  0.4494,  0.0416,  0.9999, -0.0038,  0.0123,  0.0081],
#         [ 0.5756,  0.4483,  0.0449,  0.9999, -0.0038,  0.0123,  0.0081],
#         [ 0.5852,  0.4491,  0.0477,  0.9999, -0.0038,  0.0123,  0.0081],
#         [ 0.5933,  0.4518,  0.0500,  0.9999, -0.0038,  0.0123,  0.0081],
#         [ 0.5999,  0.4560,  0.0519,  0.9999, -0.0038,  0.0123,  0.0081],
#         [ 0.6052,  0.4618,  0.0533,  0.9999, -0.0038,  0.0123,  0.0081],
#         [ 0.6092,  0.4687,  0.0543,  0.9999, -0.0038,  0.0123,  0.0081],
# ...

# %% [markdown]
# # DNN Bot

# %%
from bot_DNN import aux_bot_DNN

# Create bot and train
bot_DNN = aux_bot_DNN(drive_path = './', pos_path = "/matlab/training/data/2024_02_03_14_22_02/positions_trim_new.csv", motor_path = "/matlab/training/data/2024_02_03_14_22_02/training_waypoints_matrix.mat",
              train_forward=False, train_inverse=False, normalize=True)
# Out:
# Connected:  cuda:0
# Loaded positions:  (12498, 7)
# Loaded inputs:  (12498, 9)
# [aux_net] Forward model succesfully loaded
# [aux_net] Inverse model succesfully loaded

# %% [markdown]
# # Training functions

# %%
# %matplotlib inline

import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
import torch.optim as optim
import sys
import os
import time
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from torch.utils.data import Dataset
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt
from matplotlib.colors import Normalize
from scipy.io import savemat
import scipy.io

class aux_bot():

    def __init__(self,drive_path = None, pos_path = None, motor_path = None,
                 train_forward = False, train_inverse = False,
                 normalize=True):

        # Setup device
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        print("Connected: ", self.device)
        self.pos_path = pos_path
        self.motor_path = motor_path
        self.drive_path = drive_path
        self.model_path = None
        self.normalize = normalize

        # Parameter indicies
        self.m_inputs = 9
        self.n_outputs = 7
        self.motor_slice = slice(0,self.m_inputs)
        self.end_slice = slice(self.m_inputs,self.m_inputs+self.n_outputs)
        self.end_slice_xyz = slice(self.m_inputs,self.m_inputs+3)
        self.end_slice_q = slice(self.m_inputs+3,self.m_inputs+7)
        self.input_size = self.motor_slice.stop - self.motor_slice.start
        self.output_size = self.end_slice.stop - self.end_slice.start

        # Constant for forward model
        self.BATCH_SIZE = 16
        self.EPOCHS = 100
        self.LEARNING_RATE = 0.0005
        self.MOMENTUM = 0.9
        self.WEIGHT_DECAY = 0
        self.DROPOUT = 0
        self.LAYERS = 1

        # Upload data as fixed length trajectories instead of single points
        self.MAX_SEQ_LENGTH = 80
        self.upload_data()

        # Train forward model
        if  train_forward:
            self.fk_net = self.forward_net(inputs = self.input_size,
                                           hidden_lstm = 512,
                                           hidden = 1552,
                                           outputs = self.output_size,
                                           num_layers = 1,
                                           dropout = self.DROPOUT,
                                           device = self.device)

            self.fk_net.load_state_dict(torch.load(drive_path + '/models/forward_2024_02_02-16_40_20_3.213mm'))

            # Train and evaluate
            self.train_forward(self.fk_net,self.EPOCHS,self.LEARNING_RATE,self.MOMENTUM,self.WEIGHT_DECAY,annealing=True)
            self.eval_model_forward(self.fk_net,self.fk_train_loss)

        # Load forward model instead
        if not train_forward:
            self.fk_net = self.forward_net(hidden_lstm=512, hidden=1552)
            self.fk_net.load_state_dict(torch.load(drive_path + '/models/forward_2024_02_02-16_40_20_3.213mm'))
            self.fk_net.eval()
            print("[aux_net] Forward model succesfully loaded")

        # Constant for inverse model
        self.EPOCHS = 50
        self.LEARNING_RATE = 0.001
        self.MOMENTUM = 0.9
        self.DROPOUT = 0
        self.LAYERS = 1
        self.GAMMA = 0.9

        # Train inverse model
        if  train_inverse:
            self.ik_net = self.inverse_net(hidden=1552,
                                           hidden_lstm = 512,
                                           inputs=self.output_size,
                                           outputs=self.input_size,
                                           device=self.device,
                                           dropout=self.DROPOUT,
                                           num_layers=self.LAYERS,
                                           linear_depth=3)
            # Bootstrap off previous run
            self.ik_net.load_state_dict(torch.load(drive_path + '/models/inverse_2024_02_02-17_46_11_14.739pwm'))

            # Train and evaluate
            self.train_inverse(self.ik_net,self.EPOCHS,self.LEARNING_RATE,self.MOMENTUM,self.WEIGHT_DECAY,annealing=True)
            self.eval_model_inverse(self.ik_net,self.ik_train_loss)

        # Load inverse model instead
        if not train_inverse:
            self.ik_net = self.inverse_net(hidden_lstm=512, hidden=1552,device=self.device,linear_depth=3)
            self.ik_net.load_state_dict(torch.load(drive_path + '/models/inverse_2024_02_04-22_48_17_10.251mm'))
            self.ik_net.eval()
            self.ik_net.to(self.device)
            print("[aux_net] Inverse model succesfully loaded")

    ############################
    # DATA PRE-PROCESSING
    ############################
    def normalize_data(self,data,d_type="full"):
        if d_type == "full":
            data = (data-self.min_scale)/(self.max_scale-self.min_scale)
        elif d_type == "motor":
                data = (data-self.min_scale[self.motor_slice])/(self.max_scale[self.motor_slice]-self.min_scale[self.motor_slice])
        elif d_type == "end_full":
            data = (data-self.min_scale[self.end_slice])/(self.max_scale[self.end_slice]-self.min_scale[self.end_slice])
        return data

    # Return data to original units
    def denormalize_data(self, data, d_type="full"):
        if isinstance(data, np.ndarray):
            if d_type == "full":
                data = data*(self.max_scale-self.min_scale)+self.min_scale
            elif d_type == "motor":
                    data = data*(self.max_scale[self.motor_slice]-self.min_scale[self.motor_slice])+self.min_scale[self.motor_slice]
            elif d_type == "end_full":
                data = data*(self.max_scale[self.end_slice]-self.min_scale[self.end_slice])+self.min_scale[self.end_slice]
            return data

        elif isinstance(data, torch.Tensor):
            if d_type == "full":
                data = data*(self.max_scale_torch-self.min_scale_torch)+self.min_scale_torch
            elif d_type == "motor":
                    data = data*(self.max_scale_torch[self.motor_slice]-self.min_scale_torch[self.motor_slice])+self.min_scale_torch[self.motor_slice]
            elif d_type == "end_full":
                data = data*(self.max_scale_torch[self.end_slice]-self.min_scale_torch[self.end_slice])+self.min_scale_torch[self.end_slice]
            return data

    class SequenceDataset(Dataset):
        def __init__(self, data_array, input_range, output_range, sequence_length=5,
                     shuffle=True, train=False, test=False, split=0.8,inverse=False):
            self.shuffle = shuffle
            self.sequence_length = sequence_length
            self.train = train
            self.test = test
            self.split = split
            if not inverse:
                self.y = torch.tensor(data_array[:, output_range]).float()
                self.X = torch.tensor(data_array[:, input_range]).float()
            else:
                self.y = torch.tensor(data_array[:, input_range]).float()
                self.X = torch.tensor(data_array[:, output_range]).float()
            self.N = self.X.shape[0]

            # Data shuffling
            if shuffle == True:
                torch.manual_seed(7)
                self.idx = torch.randperm(self.N)

            # Handle train-test split
            if self.train:
                self.N = int(self.N*self.split)
                if self.shuffle: self.idx = self.idx[0:self.N]
            if self.test:
                self.N = int(self.N*(1-self.split))
                if self.shuffle: self.idx = self.idx[-self.N:]

        def __len__(self):
            return self.N

        def __getitem__(self, i):
            assert 0 <= i < self.N, "Index out of bounds for sequence"

            if self.shuffle: i = self.idx[i]

            # Calculate the start index of the block
            block_num = i // self.sequence_length
            start_idx = block_num * self.sequence_length
            end_idx = i

            x = self.X[start_idx : end_idx + 1,:]
            x_len = end_idx - start_idx + 1

            # If x is shorter than the sequence length, pad with zeros along that dimension
            if x_len < self.sequence_length:
                # Calculate the number of rows to pad
                padding_size = self.sequence_length - x_len

                # Create a zero tensor for padding with the same number of columns as x
                padding = torch.zeros((padding_size, x.shape[1]), dtype=x.dtype)-1

                # Pad x at the beginning with the padding tensor
                x = torch.cat((x,padding), dim=0)

            return x, self.y[i]

        def get_all_items(self):
            Xs, Ys = [], []
            for i in range(self.N):
                x, y = self.__getitem__(i)
                Xs.append(x)
                Ys.append(y)
            return torch.stack(Xs), torch.stack(Ys)

    # Uploads training data
    def upload_data(self):
        # Position data
        self.pos_data = np.loadtxt(self.drive_path + self.pos_path, skiprows = 1, delimiter=',', dtype = 'float32',
                               usecols = tuple(range(3, 3 + self.output_size)))

        # Motor data
        motor_data = scipy.io.loadmat(self.drive_path+self.motor_path)
        self.motor_data = motor_data['points']
        data_len = np.shape(self.pos_data)[0]
        self.motor_data = self.motor_data[0:data_len, :]

        print(np.shape(self.pos_data))
        print(np.shape(self.motor_data))

        # Combine arrays into one
        self.data = np.hstack((self.motor_data,self.pos_data))

        self.data[:,self.end_slice_xyz] *= 10e2
        self.data_raw = np.copy(self.data)

        print("Inputs: ", self.data[0:3,self.motor_slice,])
        print("Outputs: ", self.data[0:3,self.end_slice,])

        self.min_scale = np.amin(self.data,0)
        self.min_scale[self.end_slice_q] = np.array([0,0,0,0])
        self.max_scale = np.amax(self.data,0)
        self.max_scale[self.end_slice_q] = np.array([1,1,1,1])

        self.min_scale_torch = torch.from_numpy(self.min_scale).to(self.device)
        self.max_scale_torch = torch.from_numpy(self.max_scale).to(self.device)

        if self.normalize:
            self.data = self.normalize_data(self.data)
            print("Norm inputs: ", self.data[0:3,self.motor_slice,])
            print("Norm outputs: ", self.data[0:3,self.end_slice,])


        self.test_sequence =   self.SequenceDataset(self.data,
                                                        input_range = self.motor_slice,
                                                        output_range = self.end_slice,
                                                        sequence_length = self.MAX_SEQ_LENGTH,
                                                        shuffle = True,
                                                        train = True,
                                                        inverse = False)

        # FORWARD train sequences
        self.forward_train_data = self.SequenceDataset(self.data,
                                                        input_range = self.motor_slice,
                                                        output_range = self.end_slice,
                                                        sequence_length = self.MAX_SEQ_LENGTH,
                                                        shuffle = True,
                                                        train = True,
                                                        inverse = False)

        # FORWARD test sequences
        self.forward_test_data = self.SequenceDataset(self.data,
                                                        input_range = self.motor_slice,
                                                        output_range = self.end_slice,
                                                        sequence_length = self.MAX_SEQ_LENGTH,
                                                        shuffle = True,
                                                        test = True,
                                                        inverse = False)

        # Set up FORWARD data loader
        self.forward_train_loader = torch.utils.data.DataLoader(self.forward_train_data, batch_size = self.BATCH_SIZE)
        self.forward_test_loader = torch.utils.data.DataLoader(self.forward_test_data, batch_size = self.BATCH_SIZE)

        # INVERSE train sequences
        self.inverse_train_data = self.SequenceDataset(self.data,
                                                        input_range = self.motor_slice,
                                                        output_range = self.end_slice,
                                                        sequence_length = self.MAX_SEQ_LENGTH,
                                                        shuffle = True,
                                                        train = True,
                                                        inverse = True)
        # INVERSE test sequences
        self.inverse_test_data = self.SequenceDataset(self.data,
                                                        input_range = self.motor_slice,
                                                        output_range = self.end_slice,
                                                        sequence_length = self.MAX_SEQ_LENGTH,
                                                        shuffle = True,
                                                        test = True,
                                                        inverse = True)

        # Set up INVERSE data loader
        self.inverse_train_loader = torch.utils.data.DataLoader(self.inverse_train_data, batch_size=self.BATCH_SIZE)
        self.inverse_test_loader = torch.utils.data.DataLoader(self.inverse_test_data, batch_size=self.BATCH_SIZE)


    ########################
    # FORWARD NETWORK
    ########################

    class forward_net(nn.Module):
        def __init__(self, inputs=9, hidden_lstm=512, hidden=1024, outputs=7,num_layers=1,dropout=0,device=None):
            super().__init__()
            self.device = device

            self.lstm = nn.LSTM(
            input_size=inputs,
            hidden_size=hidden_lstm,
            batch_first=True,
            num_layers=num_layers,
            )

            self.fc1 = nn.Linear(2 * hidden_lstm, hidden)
            self.fc2 = nn.Linear(hidden, hidden)
            self.fc3 = nn.Linear(hidden, outputs)

            self.input_size = inputs
            self.hidden_size = hidden
            self.hidden_lstm_size = hidden_lstm
            self.output_size = outputs
            self.num_layers = num_layers
            self.dropout = nn.Dropout(dropout)

        def forward(self,x):
            batch_size = x.shape[0]
            h0 = torch.zeros(self.num_layers, batch_size, self.hidden_lstm_size).requires_grad_().to(self.device)
            c0 = torch.zeros(self.num_layers, batch_size, self.hidden_lstm_size).requires_grad_().to(self.device)

            _, (hn, cn) = self.lstm(x, (h0, c0))

            y = torch.cat((hn[-1], cn[-1]), dim=1)

            y = F.relu(y)
            y = self.fc1(y)
            y = F.relu(y)
            y = self.fc2(y)
            y = F.relu(y)
            y = self.fc3(y)

            return y

    # Training function
    def train_forward(self,fk_net,epochs=10, lr=0.01, momentum=0.9, decay=0.0, verbose=1,annealing=True):
        fk_net.to(self.device)
        losses = []
        criterion = nn.MSELoss()
        self.optimizer = optim.Adam(fk_net.parameters(), lr, weight_decay=decay)

        # Aneal learning rate
        if annealing:
            scheduler = optim.lr_scheduler.ExponentialLR(self.optimizer, gamma=0.95)

        for epoch in range(epochs):
            sum_loss = 0
            loss_list = []
            i = 0
            for X, y in self.forward_train_loader:
                X, y = X.to(self.device), y.to(self.device)

                # Reset gradients
                self.optimizer.zero_grad()

                # Run network forward, backward, and then update
                y_pred = fk_net(X)

                loss = criterion(y_pred,y)
                loss.backward()
                self.optimizer.step()

                # Track performance
                loss_list.append(loss.item())
                sum_loss += loss.item()

                if i % 100 == 99:
                    if verbose:
                        print('(Epoch {}, Iter {}) loss: {:.6f}'.format(epoch + 1, i + 1, sum_loss / 100))
                    sum_loss = 0
                i+=1
            if annealing:
                scheduler.step()
            losses.append(np.mean(loss_list))
            loss_list = []
        self.fk_train_loss = losses


    def quaternion_angular_error(self, q1, q2):
        # Determine if input is numpy or torch
        if isinstance(q1, np.ndarray):
            # For NumPy arrays

            # Normalize q2 for numpy
            norm_q1 = np.linalg.norm(q1, axis=1, keepdims=True)
            q1_normalized = q1 / norm_q1

            dot_product = np.sum(q1_normalized * q2, axis=1)

            # dot_product = np.clip(dot_product, -1.0, 1.0)
            absolute_dot_product = np.abs(dot_product)
            half_angle = np.arccos(absolute_dot_product)

        elif isinstance(q1, torch.Tensor):
            # For PyTorch tensors

            # Normalize q2 for torch
            norm_q1 = torch.norm(q1, dim=1, keepdim=True)
            q1_normalized = q1 / norm_q1

            dot_product = (q1_normalized * q2).sum(dim=1).clamp(-1.0, 1.0)
            absolute_dot_product = torch.abs(dot_product)
            half_angle = torch.acos(absolute_dot_product)
        else:
            raise TypeError("Unsupported input type. Expected numpy array or torch tensor.")

        # Double to get full angle, return in degrees
        return 2 * half_angle * (180.0 / np.pi)


    # Determine model error for predicting end effector pose
    def test_forward(self,fk_net,data='train'):
        accuracy = []
        err = np.array([])
        q_err = np.array([])

        # Create data loader
        if data == 'train': loader = self.forward_train_loader
        if data == 'test': loader = self.forward_test_loader

        # Run through the data
        for X, y in loader:
            X, y = X.to(self.device), y.to(self.device)

            y_pred = fk_net(X)

            # Convert back to CPU side
            y_pred = y_pred.numpy(force=True)
            y = y.numpy(force=True)

            if self.normalize:
                y_pred = self.denormalize_data(y_pred,"end_full")
                y = self.denormalize_data(y,"end_full")

            # Calculate postional error
            e = y_pred[:,0:3]-y[:,0:3]
            error = np.linalg.norm(e,axis = 1).flatten()
            accuracy.append(np.mean(error))
            err = np.append(err,error)

            # Calculate orientation error
            q_e = self.quaternion_angular_error(y_pred[:, 3:], y[:, 3:])
            q_error = q_e.flatten()
            q_err = np.append(q_err,q_error)

        return np.mean(accuracy), err, q_err

    # Plots the test accuracy of the model
    def eval_model_forward(self,fk_net,loss):
        # Plot losses during training
        plt.close('all')
        f = plt.figure()
        f.set_size_inches(16,4)
        ax1 = f.add_subplot(1,3,1)
        ax2 = f.add_subplot(1,3,2)
        ax3 = f.add_subplot(1,3,3,projection='3d')

        # Plot training loss
        ax1.plot(np.log10(loss),linewidth = 2)
        ax1.set_xlabel("Epochs",fontsize = 14)
        ax1.set_ylabel("log10(Loss)",fontsize = 14)
        ax1.set_title("Train Loss (Forward)",fontsize = 16)
        ax1.grid()

        # Determine train and test accuracy
        test_accuracy,test_error, test_q_error = self.test_forward(fk_net,data='test')
        train_accuracy, train_error, train_q_error = self.test_forward(fk_net,data='train')

        print("Train accuracy {:.10f} mm Test accuracy: {:.10f} mm".format(train_accuracy,test_accuracy))

        # Show testing accuracy
        ax2.hist(test_error,20)
        ax2.set_xlabel("Error (mm)",fontsize = 14)
        ax2.set_ylabel("Count",fontsize = 14)
        ax2.set_title("Positional Error for Test Data",fontsize = 16)
        ax2.grid()

        # Create a colormap and a normalize function based on the errors' range
        colormap = cmap=plt.cm.jet
        xyz_quat = np.zeros((len(self.forward_test_data),7))

        for i in range(len(self.forward_test_data)):
            X,y = self.forward_test_data[i]
            y = y.numpy(force=True)
            y = self.denormalize_data(y,"end_full")
            xyz_quat[i,:] = y

        # Create scatter plot of distance errors
        p = ax3.scatter(xyz_quat[:,0], xyz_quat[:,2], xyz_quat[:,1], c = test_error, cmap=plt.cm.jet,vmin=0,vmax=0.65*np.max(test_error), alpha=0.2)
        ax3.view_init(45, 45)
        cb = f.colorbar(p)
        cb.set_label("Error (mm)")
        ax3.set_xlabel("xe",fontsize = 14)
        ax3.set_ylabel("ye",fontsize = 14)
        ax3.set_zlabel("ze",fontsize = 14)
        ax3.set_title("Aux-Net Forward Model Performance",fontsize = 16)
        ax3.grid()
        plt.tight_layout()
        plt.show()

        # Save model
        model_name = 'forward_' + time.strftime('%Y_%m_%d-%H_%M_%S_') + '{:.3f}mm'.format(test_accuracy)
        torch.save(fk_net.state_dict(),self.drive_path + '/models/' + model_name)

        savemat(self.drive_path + "/metrics/" + model_name,{'test_error' : test_error,
                                                                    'test_q_error' : test_q_error})

        return test_accuracy

    #########################
    ## INVERSE NETWORK
    #########################

    class inverse_net(nn.Module):
        def __init__(self, inputs=7, hidden_lstm=512, hidden=1024, outputs=9, num_layers=1, dropout=0.1, device=None, linear_depth = None):
            super().__init__()

            self.device = device

            self.lstm = nn.LSTM(
            input_size=inputs,
            hidden_size=hidden_lstm,
            batch_first=True,
            num_layers=num_layers,
            )

            self.drop = nn.Dropout(dropout)

            # Default size
            if linear_depth == None:
                self.fc1 = nn.Linear(hidden_lstm,hidden)
                self.fc2 = nn.Linear(hidden,hidden)
                self.fc3 = nn.Linear(hidden,outputs)

            # Explore different sizes
            else:
                self.linear_layers = nn.ModuleList()  # Use nn.ModuleList
                if linear_depth == 1:
                    self.linear_layers.append(nn.Linear(2 * hidden_lstm, outputs))
                else:
                    self.linear_layers.append(nn.Linear(2 * hidden_lstm, hidden))
                    for _ in range(1, linear_depth - 1):
                        self.linear_layers.append(nn.Linear(hidden, hidden))
                    self.linear_layers.append(nn.Linear(hidden, outputs))

            self.input_size = inputs
            self.hidden_size = hidden
            self.hidden_lstm_size = hidden_lstm
            self.output_size = outputs
            self.num_layers = num_layers
            self.dropout = dropout
            self.linear_depth = linear_depth

        def forward(self,y):

            batch_size = y.shape[0]
            h0 = torch.zeros(self.num_layers, batch_size, self.hidden_lstm_size).requires_grad_().to(self.device)
            c0 = torch.zeros(self.num_layers, batch_size, self.hidden_lstm_size).requires_grad_().to(self.device)

            _, (hn, cn) = self.lstm(y, (h0, c0))
            x = torch.cat((hn[-1], cn[-1]), dim=1)

            x = self.drop(x)

            # Default architecture
            if self.linear_depth == None:
                x = F.relu(x)
                x = self.fc1(x)
                x = F.relu(x)
                x = self.fc2(x)
                x = F.relu(x)
                x = self.fc3(x)

            # n-dimensional
            else:
                for fc in self.linear_layers:
                    x = F.relu(x)
                    x = fc(x)

            return x

    # Training function
    def train_inverse(self,ik_net,epochs=10, lr=0.01, momentum=0.9, decay=0.0, verbose=1, annealing=True):
        ik_net.to(self.device)
        losses = []
        criterion = nn.MSELoss()
        self.optimizer = optim.Adam(ik_net.parameters(), lr, weight_decay=decay)

        # Anneal the learing rate over time
        if annealing:
            scheduler = optim.lr_scheduler.ExponentialLR(self.optimizer, gamma=self.GAMMA)

        for epoch in range(epochs):
            sum_loss = 0
            loss_list = []
            i = 0
            for X, y in self.inverse_train_loader:
                X, y = X.to(self.device), y.to(self.device)

                # Reset gradients
                self.optimizer.zero_grad()

                # Run network forward, backward, and then update
                y_pred = ik_net(X)
                loss = criterion(y_pred,y)
                loss.backward()
                self.optimizer.step()

                # Track performance
                loss_list.append(loss.item())
                sum_loss += loss.item()
                if i % 100 == 99:
                    if verbose:
                        print('(Epoch {}, Iter {}) loss: {:.6f}'.format(epoch + 1, i + 1, sum_loss / 100))
                    sum_loss = 0
                i += 1
            if annealing:
                scheduler.step()
            losses.append(np.mean(loss_list))
            loss_list = []
        self.ik_train_loss = losses

    # Determine model error from predicting motor inputs
    def test_inverse(self,ik_net,data='train'):
        accuracy = []
        err = np.array([])
        dist = np.array([])

        # Create data loader
        if data == 'train': loader = self.inverse_train_loader
        if data == 'test': loader = self.inverse_test_loader

        # Run through the data
        for X, y in loader:
            X, y = X.to(self.device), y.to(self.device)

            # Run network forward, backward, and then update
            y_pred = ik_net(X)

            # Denormalize data to find error
            if self.normalize:
                y_pred = self.denormalize_data(y_pred.numpy(force=True),"motor")
                y = self.denormalize_data(y.numpy(force=True),"motor")
                X = self.denormalize_data(X.numpy(force=True),"end_full")

            # Calculate error
            e = y_pred-y
            error = np.linalg.norm(e,axis = 1).flatten()
            accuracy.append(np.mean(error))
            err = np.append(err,error)

            # Record distance of this trajectory
            X = X[:,:,:3]
            diffs = np.diff(X, axis=1)  # This will reduce the 2nd dimension by 1
            point_dist = np.linalg.norm(diffs, axis=-1)
            seq_dis = np.sum(point_dist, axis=1)
            dist = np.append(dist, seq_dis)

        return np.mean(accuracy), err, dist

    # Plots the test accuracy of the model
    def eval_model_inverse(self,ik_net,loss):
        # Plot losses during training
        f = plt.figure()
        f.set_size_inches(20,5)
        ax1 = f.add_subplot(1,3,1)
        ax2 = f.add_subplot(1,3,2)
        ax3 = f.add_subplot(1,3,3,projection='3d')

        # Plot training loss
        ax1.plot(np.log10(loss),linewidth = 2)
        ax1.set_xlabel("Epochs",fontsize = 14)
        ax1.set_ylabel("log10(Loss)",fontsize = 14)
        ax1.set_title("Train Loss (Inverse)",fontsize = 16)
        ax1.grid()

        # Determine train and test accuracy
        test_accuracy,test_error,test_dist = self.test_inverse(ik_net,data='test')
        train_accuracy, train_error,train_dist = self.test_inverse(ik_net,data='train')
        self.test_accuracy = test_accuracy

        print("Train accuracy {:.10f} mm Test accuracy: {:.10f} mm".format(train_accuracy,test_accuracy))

        # Show testing accuracy
        ax2.hist(test_error,int(np.sqrt(len(test_error))))
        ax2.set_xlabel("Error (mm)",fontsize = 14)
        ax2.set_ylabel("Count",fontsize = 14)
        ax2.set_title("Error for Test Data",fontsize = 16)
        ax2.set_xlim(0,25)
        ax2.grid()

        # Create a colormap and a normalize function based on the errors' range
        colormap = cmap=plt.cm.jet
        norm = Normalize(vmin=test_error.min(), vmax=0.6*test_error.max())

        for i in range(len(self.inverse_test_data)):
            X,y = self.inverse_test_data[i]
            X = X.numpy(force=True)
            X = self.denormalize_data(X,"end_full")
            color = colormap(norm(test_error[i]))
            plt.plot(X[:,0],X[:,2],X[:,1],marker='o', color=color, alpha=0.2)

        # Plot formatting
        ax3.view_init(45, 45)
        cb = f.colorbar(plt.cm.ScalarMappable(cmap=colormap, norm=norm), ax=ax3, shrink=0.6)
        cb.set_label("Error (mm)")
        ax3.set_xlabel("xe",fontsize = 14)
        ax3.set_ylabel("ye",fontsize = 14)
        ax3.set_zlabel("ze",fontsize = 14)
        ax3.set_title("Aux-Net Inverse Model Performance",fontsize = 16)
        ax3.grid()
        plt.tight_layout()
        plt.show()

        # Save model
        model_name = 'inverse_'+time.strftime('%Y_%m_%d-%H_%M_%S_') + '{:.3f}mm'.format(test_accuracy)
        torch.save(ik_net.state_dict(),self.drive_path +'/models/'+model_name)

        savemat(self.drive_path + "/metrics/" + model_name,{'test_error' : test_error})


        f = plt.figure()
        plt.scatter(train_dist,train_error)
        plt.scatter(test_dist,test_error)
        plt.legend(["test","train"])
        plt.xlabel("trajectory distance (mm)",fontsize = 14)
        plt.ylabel("inverse model error (mm)",fontsize = 14)
        plt.show()

        return test_accuracy

    # Train and validation for Bayesian optimization of model
    def train_validate(self, lr: float, hidden_lstm: float, hidden: float):

            hidden_lstm = int(hidden_lstm)
            hidden = int(hidden)

            self.optima_net = self.inverse_net(hidden=hidden,
                                    hidden_lstm = hidden_lstm,
                                    inputs=self.output_size,
                                    outputs=self.input_size,
                                    device=self.device,
                                    dropout=self.DROPOUT,
                                    num_layers=1)

            # Train and evaluate
            self.train_inverse(self.optima_net,self.EPOCHS,lr,self.MOMENTUM,self.WEIGHT_DECAY,annealing=True,verbose=0)
            validation,_,_ = self.test_inverse(self.optima_net,data="test")

            return -validation

    # Run inverse prediction
    def inverse_prediction(self,input_path=None,output_path=None):
        with torch.no_grad():
            # Find end effector position we want to predict for inverse verification
            if input_path == None:

                n_points = 7500

                prediction_data = self.inverse_test_data

                # Gather all sequence data
                X, y = prediction_data.get_all_items()
                Y_pred = self.ik_net(X.to(self.device))

                # Create numpy arrays
                Y_pred = Y_pred.cpu()
                Y_pred = self.denormalize_data(Y_pred.numpy(),"motor")
                y = self.denormalize_data(y.numpy(),"motor")

                print("Predicted: ", Y_pred[0:10,:])
                print("Measured: ", y[0:10,:])

                np.savetxt(self.drive_path+"/input_regression.csv",Y_pred,delimiter=",",header="dtm_13,dtm_24,de_13,de_24,dl",comments='')
                savemat(self.drive_path+"/input_regression.mat",{"output": Y_pred})

            # Generate motor trajectory
            else:
                traj = torch.from_numpy(np.loadtxt(input_path,skiprows = 1,delimiter=',',dtype = 'float32',usecols = tuple(range(0,7))))
                traj = self.normalize_data(traj,"end_full")

                self.test_sequence =   self.SequenceDataset(traj,
                                                input_range = self.motor_slice,
                                                output_range = self.end_slice,
                                                sequence_length = self.MAX_SEQ_LENGTH,
                                                shuffle = False,
                                                train = False,
                                                inverse = True)

                x_pred = self.ik_net(traj.to(self.device))
                x_pred = x_pred.cpu()
                x_pred = self.denormalize_data(x_pred,"motor").numpy(force=True)

                np.savetxt(output_path,x_pred,delimiter=",",header="dtm_13,dtm_24,de_13,de_24,dl",comments='')
                print("Trajectory saved!")

# %% [markdown]
# # Launch and train

# %%
from google.colab import drive

drive.mount('/gdrive')
drive_path = '/gdrive/My Drive/Github/aux-net'

# Create bot and train
bot = aux_bot(drive_path = drive_path, pos_path = "/matlab/training/data/2024_02_03_14_22_02/positions_trim_new.csv", motor_path = "/matlab/training/data/2024_02_03_14_22_02/training_waypoints_matrix.mat",
              train_forward=True, train_inverse=False, normalize=True)

# bot.inverse_prediction()
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# Connected:  cuda:0
# (12498, 7)
# (12498, 9)
# Inputs:  [[  0.           0.           0.           0.           0.
#     0.           0.           0.           0.        ]
#  [ -2.85625713  -5.96907981  -2.7352241   -6.40647506   2.49327677
#     1.49596606  -3.20026289  -1.55748479  -0.52943977]
#  [ -5.71251426 -11.93815962  -5.4704482  -12.81295013   4.98655355
#     2.99193213  -6.40052578  -3.11496957  -1.05887954]]
# Outputs:  [[-2.08007004e+01 -6.05276413e+00  2.43549213e+02 -7.74288410e-03
#    1.72547027e-02  8.28647800e-03  9.99786198e-01]
#  [-2.34040078e+01 -1.15404427e+01  2.43758798e+02 -7.24774599e-03
#    2.18652859e-02  8.21123179e-03  9.99700069e-01]
#  [-2.81751901e+01 -1.11318091e+01  2.47604921e+02  3.42158694e-03
#    1.82829108e-02  9.16800182e-03  9.99784529e-01]]
# Norm inputs:  [[0.88579035 0.88667244 0.87092579 0.87723304 0.88848099 0.87261845
#   0.87649407 0.8879552  0.87241105]
#  [0.87272184 0.84873248 0.8379242  0.84568952 0.90409293 0.89045104
#   0.86061504 0.87814012 0.86607882]
#  [0.85965334 0.81079253 0.8049226  0.81414599 0.91970487 0.90828364
#   0.84473602 0.86832503 0.85974659]]
# Norm outputs:  [[ 0.48537115  0.49121471  0.01645531 -0.00774288  0.0172547   0.00828648
#    0.9997862 ]
#  [ 0.48104042  0.4816622   0.01731801 -0.00724775  0.02186529  0.00821123
#    0.99970007]
#  [ 0.47310332  0.48237352  0.03314952  0.00342159  0.01828291  0.009168
#    0.99978453]]
# (Epoch 1, Iter 100) loss: 0.000306
# (Epoch 1, Iter 200) loss: 0.000234
# (Epoch 1, Iter 300) loss: 0.000186
# (Epoch 1, Iter 400) loss: 0.000192
# (Epoch 1, Iter 500) loss: 0.000158
# (Epoch 1, Iter 600) loss: 0.000182
# (Epoch 2, Iter 100) loss: 0.000148
# (Epoch 2, Iter 200) loss: 0.000133
# (Epoch 2, Iter 300) loss: 0.000114
# (Epoch 2, Iter 400) loss: 0.000125
# (Epoch 2, Iter 500) loss: 0.000119
# (Epoch 2, Iter 600) loss: 0.000133
# (Epoch 3, Iter 100) loss: 0.000112
# (Epoch 3, Iter 200) loss: 0.000121
# (Epoch 3, Iter 300) loss: 0.000099
# (Epoch 3, Iter 400) loss: 0.000110
# (Epoch 3, Iter 500) loss: 0.000114
# (Epoch 3, Iter 600) loss: 0.000115
# (Epoch 4, Iter 100) loss: 0.000100
# (Epoch 4, Iter 200) loss: 0.000101
# (Epoch 4, Iter 300) loss: 0.000088
# (Epoch 4, Iter 400) loss: 0.000101
# (Epoch 4, Iter 500) loss: 0.000113
# (Epoch 4, Iter 600) loss: 0.000100
# (Epoch 5, Iter 100) loss: 0.000102
# (Epoch 5, Iter 200) loss: 0.000094
# (Epoch 5, Iter 300) loss: 0.000076
# (Epoch 5, Iter 400) loss: 0.000091
# (Epoch 5, Iter 500) loss: 0.000102
# (Epoch 5, Iter 600) loss: 0.000090
# (Epoch 6, Iter 100) loss: 0.000092
# (Epoch 6, Iter 200) loss: 0.000084
# (Epoch 6, Iter 300) loss: 0.000075
# (Epoch 6, Iter 400) loss: 0.000084
# (Epoch 6, Iter 500) loss: 0.000097
# (Epoch 6, Iter 600) loss: 0.000083
# (Epoch 7, Iter 100) loss: 0.000087
# (Epoch 7, Iter 200) loss: 0.000079
# (Epoch 7, Iter 300) loss: 0.000074
# (Epoch 7, Iter 400) loss: 0.000092
# (Epoch 7, Iter 500) loss: 0.000092
# (Epoch 7, Iter 600) loss: 0.000075
# (Epoch 8, Iter 100) loss: 0.000077
# (Epoch 8, Iter 200) loss: 0.000071
# (Epoch 8, Iter 300) loss: 0.000066
# (Epoch 8, Iter 400) loss: 0.000087
# (Epoch 8, Iter 500) loss: 0.000079
# (Epoch 8, Iter 600) loss: 0.000075
# (Epoch 9, Iter 100) loss: 0.000070
# (Epoch 9, Iter 200) loss: 0.000068
# (Epoch 9, Iter 300) loss: 0.000066
# (Epoch 9, Iter 400) loss: 0.000077
# (Epoch 9, Iter 500) loss: 0.000073
# (Epoch 9, Iter 600) loss: 0.000065
# (Epoch 10, Iter 100) loss: 0.000070
# (Epoch 10, Iter 200) loss: 0.000068
# (Epoch 10, Iter 300) loss: 0.000059
# (Epoch 10, Iter 400) loss: 0.000081
# (Epoch 10, Iter 500) loss: 0.000065
# (Epoch 10, Iter 600) loss: 0.000063
# (Epoch 11, Iter 100) loss: 0.000061
# (Epoch 11, Iter 200) loss: 0.000062
# (Epoch 11, Iter 300) loss: 0.000055
# (Epoch 11, Iter 400) loss: 0.000076
# (Epoch 11, Iter 500) loss: 0.000058
# (Epoch 11, Iter 600) loss: 0.000060
# (Epoch 12, Iter 100) loss: 0.000054
# (Epoch 12, Iter 200) loss: 0.000057
# (Epoch 12, Iter 300) loss: 0.000052
# (Epoch 12, Iter 400) loss: 0.000073
# (Epoch 12, Iter 500) loss: 0.000059
# (Epoch 12, Iter 600) loss: 0.000059
# (Epoch 13, Iter 100) loss: 0.000052
# (Epoch 13, Iter 200) loss: 0.000055
# (Epoch 13, Iter 300) loss: 0.000051
# (Epoch 13, Iter 400) loss: 0.000073
# (Epoch 13, Iter 500) loss: 0.000055
# (Epoch 13, Iter 600) loss: 0.000056
# (Epoch 14, Iter 100) loss: 0.000052
# (Epoch 14, Iter 200) loss: 0.000054
# (Epoch 14, Iter 300) loss: 0.000048
# (Epoch 14, Iter 400) loss: 0.000065
# (Epoch 14, Iter 500) loss: 0.000051
# (Epoch 14, Iter 600) loss: 0.000051
# (Epoch 15, Iter 100) loss: 0.000048
# (Epoch 15, Iter 200) loss: 0.000049
# (Epoch 15, Iter 300) loss: 0.000045
# (Epoch 15, Iter 400) loss: 0.000057
# (Epoch 15, Iter 500) loss: 0.000048
# (Epoch 15, Iter 600) loss: 0.000049
# (Epoch 16, Iter 100) loss: 0.000044
# (Epoch 16, Iter 200) loss: 0.000045
# (Epoch 16, Iter 300) loss: 0.000042
# (Epoch 16, Iter 400) loss: 0.000052
# (Epoch 16, Iter 500) loss: 0.000045
# (Epoch 16, Iter 600) loss: 0.000046
# (Epoch 17, Iter 100) loss: 0.000043
# (Epoch 17, Iter 200) loss: 0.000046
# (Epoch 17, Iter 300) loss: 0.000042
# (Epoch 17, Iter 400) loss: 0.000049
# (Epoch 17, Iter 500) loss: 0.000043
# (Epoch 17, Iter 600) loss: 0.000043
# (Epoch 18, Iter 100) loss: 0.000041
# (Epoch 18, Iter 200) loss: 0.000049
# (Epoch 18, Iter 300) loss: 0.000042
# (Epoch 18, Iter 400) loss: 0.000047
# (Epoch 18, Iter 500) loss: 0.000043
# (Epoch 18, Iter 600) loss: 0.000044
# (Epoch 19, Iter 100) loss: 0.000040
# (Epoch 19, Iter 200) loss: 0.000040
# (Epoch 19, Iter 300) loss: 0.000038
# (Epoch 19, Iter 400) loss: 0.000046
# (Epoch 19, Iter 500) loss: 0.000041
# (Epoch 19, Iter 600) loss: 0.000040
# (Epoch 20, Iter 100) loss: 0.000039
# (Epoch 20, Iter 200) loss: 0.000040
# (Epoch 20, Iter 300) loss: 0.000038
# (Epoch 20, Iter 400) loss: 0.000043
# (Epoch 20, Iter 500) loss: 0.000039
# (Epoch 20, Iter 600) loss: 0.000042
# (Epoch 21, Iter 100) loss: 0.000036
# (Epoch 21, Iter 200) loss: 0.000038
# (Epoch 21, Iter 300) loss: 0.000036
# (Epoch 21, Iter 400) loss: 0.000041
# (Epoch 21, Iter 500) loss: 0.000037
# (Epoch 21, Iter 600) loss: 0.000038
# (Epoch 22, Iter 100) loss: 0.000035
# (Epoch 22, Iter 200) loss: 0.000037
# (Epoch 22, Iter 300) loss: 0.000035
# (Epoch 22, Iter 400) loss: 0.000041
# (Epoch 22, Iter 500) loss: 0.000037
# (Epoch 22, Iter 600) loss: 0.000036
# (Epoch 23, Iter 100) loss: 0.000033
# (Epoch 23, Iter 200) loss: 0.000036
# (Epoch 23, Iter 300) loss: 0.000034
# (Epoch 23, Iter 400) loss: 0.000039
# (Epoch 23, Iter 500) loss: 0.000036
# (Epoch 23, Iter 600) loss: 0.000035
# (Epoch 24, Iter 100) loss: 0.000032
# (Epoch 24, Iter 200) loss: 0.000035
# (Epoch 24, Iter 300) loss: 0.000034
# (Epoch 24, Iter 400) loss: 0.000038
# (Epoch 24, Iter 500) loss: 0.000033
# (Epoch 24, Iter 600) loss: 0.000034
# (Epoch 25, Iter 100) loss: 0.000031
# (Epoch 25, Iter 200) loss: 0.000033
# (Epoch 25, Iter 300) loss: 0.000031
# (Epoch 25, Iter 400) loss: 0.000037
# (Epoch 25, Iter 500) loss: 0.000033
# (Epoch 25, Iter 600) loss: 0.000032
# (Epoch 26, Iter 100) loss: 0.000031
# (Epoch 26, Iter 200) loss: 0.000032
# (Epoch 26, Iter 300) loss: 0.000030
# (Epoch 26, Iter 400) loss: 0.000036
# (Epoch 26, Iter 500) loss: 0.000032
# (Epoch 26, Iter 600) loss: 0.000031
# (Epoch 27, Iter 100) loss: 0.000029
# (Epoch 27, Iter 200) loss: 0.000031
# (Epoch 27, Iter 300) loss: 0.000029
# (Epoch 27, Iter 400) loss: 0.000034
# (Epoch 27, Iter 500) loss: 0.000031
# (Epoch 27, Iter 600) loss: 0.000030
# (Epoch 28, Iter 100) loss: 0.000028
# (Epoch 28, Iter 200) loss: 0.000030
# (Epoch 28, Iter 300) loss: 0.000029
# (Epoch 28, Iter 400) loss: 0.000033
# (Epoch 28, Iter 500) loss: 0.000030
# (Epoch 28, Iter 600) loss: 0.000029
# (Epoch 29, Iter 100) loss: 0.000027
# (Epoch 29, Iter 200) loss: 0.000029
# (Epoch 29, Iter 300) loss: 0.000027
# (Epoch 29, Iter 400) loss: 0.000033
# (Epoch 29, Iter 500) loss: 0.000029
# (Epoch 29, Iter 600) loss: 0.000028
# (Epoch 30, Iter 100) loss: 0.000026
# (Epoch 30, Iter 200) loss: 0.000028
# (Epoch 30, Iter 300) loss: 0.000027
# (Epoch 30, Iter 400) loss: 0.000032
# (Epoch 30, Iter 500) loss: 0.000029
# (Epoch 30, Iter 600) loss: 0.000026
# (Epoch 31, Iter 100) loss: 0.000026
# (Epoch 31, Iter 200) loss: 0.000027
# (Epoch 31, Iter 300) loss: 0.000026
# (Epoch 31, Iter 400) loss: 0.000031
# (Epoch 31, Iter 500) loss: 0.000028
# (Epoch 31, Iter 600) loss: 0.000026
# (Epoch 32, Iter 100) loss: 0.000025
# (Epoch 32, Iter 200) loss: 0.000026
# (Epoch 32, Iter 300) loss: 0.000025
# (Epoch 32, Iter 400) loss: 0.000030
# (Epoch 32, Iter 500) loss: 0.000027
# (Epoch 32, Iter 600) loss: 0.000025
# (Epoch 33, Iter 100) loss: 0.000025
# (Epoch 33, Iter 200) loss: 0.000025
# (Epoch 33, Iter 300) loss: 0.000025
# (Epoch 33, Iter 400) loss: 0.000030
# (Epoch 33, Iter 500) loss: 0.000026
# (Epoch 33, Iter 600) loss: 0.000025
# (Epoch 34, Iter 100) loss: 0.000024
# (Epoch 34, Iter 200) loss: 0.000025
# (Epoch 34, Iter 300) loss: 0.000024
# (Epoch 34, Iter 400) loss: 0.000028
# (Epoch 34, Iter 500) loss: 0.000025
# (Epoch 34, Iter 600) loss: 0.000024
# (Epoch 35, Iter 100) loss: 0.000024
# (Epoch 35, Iter 200) loss: 0.000024
# (Epoch 35, Iter 300) loss: 0.000023
# (Epoch 35, Iter 400) loss: 0.000027
# (Epoch 35, Iter 500) loss: 0.000024
# (Epoch 35, Iter 600) loss: 0.000023
# (Epoch 36, Iter 100) loss: 0.000023
# (Epoch 36, Iter 200) loss: 0.000023
# (Epoch 36, Iter 300) loss: 0.000023
# (Epoch 36, Iter 400) loss: 0.000026
# (Epoch 36, Iter 500) loss: 0.000024
# (Epoch 36, Iter 600) loss: 0.000023
# (Epoch 37, Iter 100) loss: 0.000022
# (Epoch 37, Iter 200) loss: 0.000023
# (Epoch 37, Iter 300) loss: 0.000022
# (Epoch 37, Iter 400) loss: 0.000026
# (Epoch 37, Iter 500) loss: 0.000023
# (Epoch 37, Iter 600) loss: 0.000022
# (Epoch 38, Iter 100) loss: 0.000022
# (Epoch 38, Iter 200) loss: 0.000022
# (Epoch 38, Iter 300) loss: 0.000022
# (Epoch 38, Iter 400) loss: 0.000025
# (Epoch 38, Iter 500) loss: 0.000022
# (Epoch 38, Iter 600) loss: 0.000022
# (Epoch 39, Iter 100) loss: 0.000022
# (Epoch 39, Iter 200) loss: 0.000021
# (Epoch 39, Iter 300) loss: 0.000021
# (Epoch 39, Iter 400) loss: 0.000024
# (Epoch 39, Iter 500) loss: 0.000022
# (Epoch 39, Iter 600) loss: 0.000021
# (Epoch 40, Iter 100) loss: 0.000021
# (Epoch 40, Iter 200) loss: 0.000021
# (Epoch 40, Iter 300) loss: 0.000021
# (Epoch 40, Iter 400) loss: 0.000024
# (Epoch 40, Iter 500) loss: 0.000022
# (Epoch 40, Iter 600) loss: 0.000021
# (Epoch 41, Iter 100) loss: 0.000021
# (Epoch 41, Iter 200) loss: 0.000020
# (Epoch 41, Iter 300) loss: 0.000021
# (Epoch 41, Iter 400) loss: 0.000023
# (Epoch 41, Iter 500) loss: 0.000021
# (Epoch 41, Iter 600) loss: 0.000021
# (Epoch 42, Iter 100) loss: 0.000020
# (Epoch 42, Iter 200) loss: 0.000020
# (Epoch 42, Iter 300) loss: 0.000020
# (Epoch 42, Iter 400) loss: 0.000023
# (Epoch 42, Iter 500) loss: 0.000021
# (Epoch 42, Iter 600) loss: 0.000020
# (Epoch 43, Iter 100) loss: 0.000020
# (Epoch 43, Iter 200) loss: 0.000020
# (Epoch 43, Iter 300) loss: 0.000020
# (Epoch 43, Iter 400) loss: 0.000022
# (Epoch 43, Iter 500) loss: 0.000020
# (Epoch 43, Iter 600) loss: 0.000020
# (Epoch 44, Iter 100) loss: 0.000020
# (Epoch 44, Iter 200) loss: 0.000019
# (Epoch 44, Iter 300) loss: 0.000019
# (Epoch 44, Iter 400) loss: 0.000021
# (Epoch 44, Iter 500) loss: 0.000020
# (Epoch 44, Iter 600) loss: 0.000019
# (Epoch 45, Iter 100) loss: 0.000019
# (Epoch 45, Iter 200) loss: 0.000019
# (Epoch 45, Iter 300) loss: 0.000019
# (Epoch 45, Iter 400) loss: 0.000021
# (Epoch 45, Iter 500) loss: 0.000019
# (Epoch 45, Iter 600) loss: 0.000019
# (Epoch 46, Iter 100) loss: 0.000019
# (Epoch 46, Iter 200) loss: 0.000019
# (Epoch 46, Iter 300) loss: 0.000019
# (Epoch 46, Iter 400) loss: 0.000021
# (Epoch 46, Iter 500) loss: 0.000019
# (Epoch 46, Iter 600) loss: 0.000019
# (Epoch 47, Iter 100) loss: 0.000019
# (Epoch 47, Iter 200) loss: 0.000018
# (Epoch 47, Iter 300) loss: 0.000019
# (Epoch 47, Iter 400) loss: 0.000020
# (Epoch 47, Iter 500) loss: 0.000019
# (Epoch 47, Iter 600) loss: 0.000018
# (Epoch 48, Iter 100) loss: 0.000018
# (Epoch 48, Iter 200) loss: 0.000018
# (Epoch 48, Iter 300) loss: 0.000018
# (Epoch 48, Iter 400) loss: 0.000020
# (Epoch 48, Iter 500) loss: 0.000019
# (Epoch 48, Iter 600) loss: 0.000018
# (Epoch 49, Iter 100) loss: 0.000018
# (Epoch 49, Iter 200) loss: 0.000018
# (Epoch 49, Iter 300) loss: 0.000018
# (Epoch 49, Iter 400) loss: 0.000020
# (Epoch 49, Iter 500) loss: 0.000018
# (Epoch 49, Iter 600) loss: 0.000018
# (Epoch 50, Iter 100) loss: 0.000018
# (Epoch 50, Iter 200) loss: 0.000018
# (Epoch 50, Iter 300) loss: 0.000018
# (Epoch 50, Iter 400) loss: 0.000019
# (Epoch 50, Iter 500) loss: 0.000018
# (Epoch 50, Iter 600) loss: 0.000017
# (Epoch 51, Iter 100) loss: 0.000018
# (Epoch 51, Iter 200) loss: 0.000017
# (Epoch 51, Iter 300) loss: 0.000018
# (Epoch 51, Iter 400) loss: 0.000019
# (Epoch 51, Iter 500) loss: 0.000018
# (Epoch 51, Iter 600) loss: 0.000017
# (Epoch 52, Iter 100) loss: 0.000017
# (Epoch 52, Iter 200) loss: 0.000017
# (Epoch 52, Iter 300) loss: 0.000017
# (Epoch 52, Iter 400) loss: 0.000019
# (Epoch 52, Iter 500) loss: 0.000018
# (Epoch 52, Iter 600) loss: 0.000017
# (Epoch 53, Iter 100) loss: 0.000017
# (Epoch 53, Iter 200) loss: 0.000017
# (Epoch 53, Iter 300) loss: 0.000017
# (Epoch 53, Iter 400) loss: 0.000019
# (Epoch 53, Iter 500) loss: 0.000017
# (Epoch 53, Iter 600) loss: 0.000017
# (Epoch 54, Iter 100) loss: 0.000017
# (Epoch 54, Iter 200) loss: 0.000017
# (Epoch 54, Iter 300) loss: 0.000017
# (Epoch 54, Iter 400) loss: 0.000018
# (Epoch 54, Iter 500) loss: 0.000017
# (Epoch 54, Iter 600) loss: 0.000017
# (Epoch 55, Iter 100) loss: 0.000017
# (Epoch 55, Iter 200) loss: 0.000017
# (Epoch 55, Iter 300) loss: 0.000017
# (Epoch 55, Iter 400) loss: 0.000018
# (Epoch 55, Iter 500) loss: 0.000017
# (Epoch 55, Iter 600) loss: 0.000016
# (Epoch 56, Iter 100) loss: 0.000017
# (Epoch 56, Iter 200) loss: 0.000016
# (Epoch 56, Iter 300) loss: 0.000017
# (Epoch 56, Iter 400) loss: 0.000018
# (Epoch 56, Iter 500) loss: 0.000017
# (Epoch 56, Iter 600) loss: 0.000016
# (Epoch 57, Iter 100) loss: 0.000016
# (Epoch 57, Iter 200) loss: 0.000016
# (Epoch 57, Iter 300) loss: 0.000017
# (Epoch 57, Iter 400) loss: 0.000018
# (Epoch 57, Iter 500) loss: 0.000017
# (Epoch 57, Iter 600) loss: 0.000016
# (Epoch 58, Iter 100) loss: 0.000016
# (Epoch 58, Iter 200) loss: 0.000016
# (Epoch 58, Iter 300) loss: 0.000016
# (Epoch 58, Iter 400) loss: 0.000018
# (Epoch 58, Iter 500) loss: 0.000017
# (Epoch 58, Iter 600) loss: 0.000016
# (Epoch 59, Iter 100) loss: 0.000016
# (Epoch 59, Iter 200) loss: 0.000016
# (Epoch 59, Iter 300) loss: 0.000016
# (Epoch 59, Iter 400) loss: 0.000017
# (Epoch 59, Iter 500) loss: 0.000016
# (Epoch 59, Iter 600) loss: 0.000016
# (Epoch 60, Iter 100) loss: 0.000016
# (Epoch 60, Iter 200) loss: 0.000016
# (Epoch 60, Iter 300) loss: 0.000016
# (Epoch 60, Iter 400) loss: 0.000017
# (Epoch 60, Iter 500) loss: 0.000016
# (Epoch 60, Iter 600) loss: 0.000016
# (Epoch 61, Iter 100) loss: 0.000016
# (Epoch 61, Iter 200) loss: 0.000016
# (Epoch 61, Iter 300) loss: 0.000016
# (Epoch 61, Iter 400) loss: 0.000017
# (Epoch 61, Iter 500) loss: 0.000016
# (Epoch 61, Iter 600) loss: 0.000015
# (Epoch 62, Iter 100) loss: 0.000016
# (Epoch 62, Iter 200) loss: 0.000016
# (Epoch 62, Iter 300) loss: 0.000016
# (Epoch 62, Iter 400) loss: 0.000017
# (Epoch 62, Iter 500) loss: 0.000016
# (Epoch 62, Iter 600) loss: 0.000015
# (Epoch 63, Iter 100) loss: 0.000015
# (Epoch 63, Iter 200) loss: 0.000015
# (Epoch 63, Iter 300) loss: 0.000016
# (Epoch 63, Iter 400) loss: 0.000017
# (Epoch 63, Iter 500) loss: 0.000016
# (Epoch 63, Iter 600) loss: 0.000015
# (Epoch 64, Iter 100) loss: 0.000015
# (Epoch 64, Iter 200) loss: 0.000015
# (Epoch 64, Iter 300) loss: 0.000016
# (Epoch 64, Iter 400) loss: 0.000017
# (Epoch 64, Iter 500) loss: 0.000016
# (Epoch 64, Iter 600) loss: 0.000015
# (Epoch 65, Iter 100) loss: 0.000015
# (Epoch 65, Iter 200) loss: 0.000015
# (Epoch 65, Iter 300) loss: 0.000016
# (Epoch 65, Iter 400) loss: 0.000016
# (Epoch 65, Iter 500) loss: 0.000015
# (Epoch 65, Iter 600) loss: 0.000015
# (Epoch 66, Iter 100) loss: 0.000015
# (Epoch 66, Iter 200) loss: 0.000015
# (Epoch 66, Iter 300) loss: 0.000015
# (Epoch 66, Iter 400) loss: 0.000016
# (Epoch 66, Iter 500) loss: 0.000015
# (Epoch 66, Iter 600) loss: 0.000015
# (Epoch 67, Iter 100) loss: 0.000015
# (Epoch 67, Iter 200) loss: 0.000015
# (Epoch 67, Iter 300) loss: 0.000015
# (Epoch 67, Iter 400) loss: 0.000016
# (Epoch 67, Iter 500) loss: 0.000015
# (Epoch 67, Iter 600) loss: 0.000014
# (Epoch 68, Iter 100) loss: 0.000015
# (Epoch 68, Iter 200) loss: 0.000015
# (Epoch 68, Iter 300) loss: 0.000015
# (Epoch 68, Iter 400) loss: 0.000016
# (Epoch 68, Iter 500) loss: 0.000015
# (Epoch 68, Iter 600) loss: 0.000014
# (Epoch 69, Iter 100) loss: 0.000015
# (Epoch 69, Iter 200) loss: 0.000015
# (Epoch 69, Iter 300) loss: 0.000015
# (Epoch 69, Iter 400) loss: 0.000016
# (Epoch 69, Iter 500) loss: 0.000015
# (Epoch 69, Iter 600) loss: 0.000014
# (Epoch 70, Iter 100) loss: 0.000015
# (Epoch 70, Iter 200) loss: 0.000015
# (Epoch 70, Iter 300) loss: 0.000015
# (Epoch 70, Iter 400) loss: 0.000016
# (Epoch 70, Iter 500) loss: 0.000015
# (Epoch 70, Iter 600) loss: 0.000014
# (Epoch 71, Iter 100) loss: 0.000015
# (Epoch 71, Iter 200) loss: 0.000015
# (Epoch 71, Iter 300) loss: 0.000015
# (Epoch 71, Iter 400) loss: 0.000016
# (Epoch 71, Iter 500) loss: 0.000015
# (Epoch 71, Iter 600) loss: 0.000014
# (Epoch 72, Iter 100) loss: 0.000014
# (Epoch 72, Iter 200) loss: 0.000015
# (Epoch 72, Iter 300) loss: 0.000015
# (Epoch 72, Iter 400) loss: 0.000016
# (Epoch 72, Iter 500) loss: 0.000015
# (Epoch 72, Iter 600) loss: 0.000014
# (Epoch 73, Iter 100) loss: 0.000014
# (Epoch 73, Iter 200) loss: 0.000015
# (Epoch 73, Iter 300) loss: 0.000015
# (Epoch 73, Iter 400) loss: 0.000015
# (Epoch 73, Iter 500) loss: 0.000015
# (Epoch 73, Iter 600) loss: 0.000014
# (Epoch 74, Iter 100) loss: 0.000014
# (Epoch 74, Iter 200) loss: 0.000014
# (Epoch 74, Iter 300) loss: 0.000015
# (Epoch 74, Iter 400) loss: 0.000015
# (Epoch 74, Iter 500) loss: 0.000015
# (Epoch 74, Iter 600) loss: 0.000014
# (Epoch 75, Iter 100) loss: 0.000014
# (Epoch 75, Iter 200) loss: 0.000014
# (Epoch 75, Iter 300) loss: 0.000015
# (Epoch 75, Iter 400) loss: 0.000015
# (Epoch 75, Iter 500) loss: 0.000015
# (Epoch 75, Iter 600) loss: 0.000014
# (Epoch 76, Iter 100) loss: 0.000014
# (Epoch 76, Iter 200) loss: 0.000014
# (Epoch 76, Iter 300) loss: 0.000014
# (Epoch 76, Iter 400) loss: 0.000015
# (Epoch 76, Iter 500) loss: 0.000014
# (Epoch 76, Iter 600) loss: 0.000014
# (Epoch 77, Iter 100) loss: 0.000014
# (Epoch 77, Iter 200) loss: 0.000014
# (Epoch 77, Iter 300) loss: 0.000014
# (Epoch 77, Iter 400) loss: 0.000015
# (Epoch 77, Iter 500) loss: 0.000014
# (Epoch 77, Iter 600) loss: 0.000014
# (Epoch 78, Iter 100) loss: 0.000014
# (Epoch 78, Iter 200) loss: 0.000014
# (Epoch 78, Iter 300) loss: 0.000014
# (Epoch 78, Iter 400) loss: 0.000015
# (Epoch 78, Iter 500) loss: 0.000014
# (Epoch 78, Iter 600) loss: 0.000014
# (Epoch 79, Iter 100) loss: 0.000014
# (Epoch 79, Iter 200) loss: 0.000014
# (Epoch 79, Iter 300) loss: 0.000014
# (Epoch 79, Iter 400) loss: 0.000015
# (Epoch 79, Iter 500) loss: 0.000014
# (Epoch 79, Iter 600) loss: 0.000014
# (Epoch 80, Iter 100) loss: 0.000014
# (Epoch 80, Iter 200) loss: 0.000014
# (Epoch 80, Iter 300) loss: 0.000014
# (Epoch 80, Iter 400) loss: 0.000015
# (Epoch 80, Iter 500) loss: 0.000014
# (Epoch 80, Iter 600) loss: 0.000013
# (Epoch 81, Iter 100) loss: 0.000014
# (Epoch 81, Iter 200) loss: 0.000014
# (Epoch 81, Iter 300) loss: 0.000014
# (Epoch 81, Iter 400) loss: 0.000015
# (Epoch 81, Iter 500) loss: 0.000014
# (Epoch 81, Iter 600) loss: 0.000013
# (Epoch 82, Iter 100) loss: 0.000014
# (Epoch 82, Iter 200) loss: 0.000014
# (Epoch 82, Iter 300) loss: 0.000014
# (Epoch 82, Iter 400) loss: 0.000015
# (Epoch 82, Iter 500) loss: 0.000014
# (Epoch 82, Iter 600) loss: 0.000013
# (Epoch 83, Iter 100) loss: 0.000014
# (Epoch 83, Iter 200) loss: 0.000014
# (Epoch 83, Iter 300) loss: 0.000014
# (Epoch 83, Iter 400) loss: 0.000015
# (Epoch 83, Iter 500) loss: 0.000014
# (Epoch 83, Iter 600) loss: 0.000013
# (Epoch 84, Iter 100) loss: 0.000014
# (Epoch 84, Iter 200) loss: 0.000014
# (Epoch 84, Iter 300) loss: 0.000014
# (Epoch 84, Iter 400) loss: 0.000015
# (Epoch 84, Iter 500) loss: 0.000014
# (Epoch 84, Iter 600) loss: 0.000013
# (Epoch 85, Iter 100) loss: 0.000014
# (Epoch 85, Iter 200) loss: 0.000014
# (Epoch 85, Iter 300) loss: 0.000014
# (Epoch 85, Iter 400) loss: 0.000015
# (Epoch 85, Iter 500) loss: 0.000014
# (Epoch 85, Iter 600) loss: 0.000013
# (Epoch 86, Iter 100) loss: 0.000014
# (Epoch 86, Iter 200) loss: 0.000014
# (Epoch 86, Iter 300) loss: 0.000014
# (Epoch 86, Iter 400) loss: 0.000015
# (Epoch 86, Iter 500) loss: 0.000014
# (Epoch 86, Iter 600) loss: 0.000013
# (Epoch 87, Iter 100) loss: 0.000014
# (Epoch 87, Iter 200) loss: 0.000014
# (Epoch 87, Iter 300) loss: 0.000014
# (Epoch 87, Iter 400) loss: 0.000015
# (Epoch 87, Iter 500) loss: 0.000014
# (Epoch 87, Iter 600) loss: 0.000013
# (Epoch 88, Iter 100) loss: 0.000014
# (Epoch 88, Iter 200) loss: 0.000014
# (Epoch 88, Iter 300) loss: 0.000014
# (Epoch 88, Iter 400) loss: 0.000015
# (Epoch 88, Iter 500) loss: 0.000014
# (Epoch 88, Iter 600) loss: 0.000013
# (Epoch 89, Iter 100) loss: 0.000014
# (Epoch 89, Iter 200) loss: 0.000014
# (Epoch 89, Iter 300) loss: 0.000014
# (Epoch 89, Iter 400) loss: 0.000014
# (Epoch 89, Iter 500) loss: 0.000014
# (Epoch 89, Iter 600) loss: 0.000013
# (Epoch 90, Iter 100) loss: 0.000014
# (Epoch 90, Iter 200) loss: 0.000014
# (Epoch 90, Iter 300) loss: 0.000014
# (Epoch 90, Iter 400) loss: 0.000014
# (Epoch 90, Iter 500) loss: 0.000014
# (Epoch 90, Iter 600) loss: 0.000013
# (Epoch 91, Iter 100) loss: 0.000013
# (Epoch 91, Iter 200) loss: 0.000014
# (Epoch 91, Iter 300) loss: 0.000014
# (Epoch 91, Iter 400) loss: 0.000014
# (Epoch 91, Iter 500) loss: 0.000014
# (Epoch 91, Iter 600) loss: 0.000013
# (Epoch 92, Iter 100) loss: 0.000013
# (Epoch 92, Iter 200) loss: 0.000014
# (Epoch 92, Iter 300) loss: 0.000014
# (Epoch 92, Iter 400) loss: 0.000014
# (Epoch 92, Iter 500) loss: 0.000014
# (Epoch 92, Iter 600) loss: 0.000013
# (Epoch 93, Iter 100) loss: 0.000013
# (Epoch 93, Iter 200) loss: 0.000014
# (Epoch 93, Iter 300) loss: 0.000014
# (Epoch 93, Iter 400) loss: 0.000014
# (Epoch 93, Iter 500) loss: 0.000014
# (Epoch 93, Iter 600) loss: 0.000013
# (Epoch 94, Iter 100) loss: 0.000013
# (Epoch 94, Iter 200) loss: 0.000014
# (Epoch 94, Iter 300) loss: 0.000014
# (Epoch 94, Iter 400) loss: 0.000014
# (Epoch 94, Iter 500) loss: 0.000014
# (Epoch 94, Iter 600) loss: 0.000013
# (Epoch 95, Iter 100) loss: 0.000013
# (Epoch 95, Iter 200) loss: 0.000013
# (Epoch 95, Iter 300) loss: 0.000014
# (Epoch 95, Iter 400) loss: 0.000014
# (Epoch 95, Iter 500) loss: 0.000014
# (Epoch 95, Iter 600) loss: 0.000013
# (Epoch 96, Iter 100) loss: 0.000013
# (Epoch 96, Iter 200) loss: 0.000013
# (Epoch 96, Iter 300) loss: 0.000014
# (Epoch 96, Iter 400) loss: 0.000014
# (Epoch 96, Iter 500) loss: 0.000014
# (Epoch 96, Iter 600) loss: 0.000013
# (Epoch 97, Iter 100) loss: 0.000013
# (Epoch 97, Iter 200) loss: 0.000013
# (Epoch 97, Iter 300) loss: 0.000013
# (Epoch 97, Iter 400) loss: 0.000014
# (Epoch 97, Iter 500) loss: 0.000014
# (Epoch 97, Iter 600) loss: 0.000013
# (Epoch 98, Iter 100) loss: 0.000013
# (Epoch 98, Iter 200) loss: 0.000013
# (Epoch 98, Iter 300) loss: 0.000013
# (Epoch 98, Iter 400) loss: 0.000014
# (Epoch 98, Iter 500) loss: 0.000014
# (Epoch 98, Iter 600) loss: 0.000013
# (Epoch 99, Iter 100) loss: 0.000013
# (Epoch 99, Iter 200) loss: 0.000013
# (Epoch 99, Iter 300) loss: 0.000013
# (Epoch 99, Iter 400) loss: 0.000014
# (Epoch 99, Iter 500) loss: 0.000014
# (Epoch 99, Iter 600) loss: 0.000013
# (Epoch 100, Iter 100) loss: 0.000013
# (Epoch 100, Iter 200) loss: 0.000013
# (Epoch 100, Iter 300) loss: 0.000013
# (Epoch 100, Iter 400) loss: 0.000014
# (Epoch 100, Iter 500) loss: 0.000014
# (Epoch 100, Iter 600) loss: 0.000013
# Train accuracy 2.7714612574 mm Test accuracy: 3.6547992200 mm
# [aux_net] Inverse model succesfully loaded

# %% [markdown]
# # Github

# %%
from google.colab import drive
drive.mount('/gdrive')

# %cd '/gdrive/My Drive/Github/aux-net'
# !git config --global user.email "kubekk101@gmail.com"
# !git config --global user.name "KubaSrc"
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Github/aux-net

# %%
# !git add .
# !git commit -m "New models"

# %%
# !git push

# %%
# !git branch --set-upstream-to=origin/main main
# !git pull
# Out:
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# remote: Enumerating objects: 127, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 100 (delta 52), reused 80 (delta 32), pack-reused 0
# Receiving objects: 100% (100/100), 18.65 MiB | 5.04 MiB/s, done.
# Resolving deltas: 100% (52/52), completed with 16 local objects.
# From https://github.com/KubaSrc/aux-net
#    676b259..81930d0  main       -> origin/main
# Updating 676b259..81930d0
# Updating files: 100% (114/114), done.
# Fast-forward
#  figures/instron/spf.png                                         |   Bin 160373 -> 151150 bytes
#  figures/instron/spt.png                                         |   Bin 219394 -> 187837 bytes
#  figures/instron/ssf.png                                         |   Bin 121567 -> 109309 bytes
#  figures/instron/sst.png                                         |   Bin 142498 -> 122988 bytes
#  figures/instron/tsf.png                                         |   Bin 90145 -> 82276 bytes
#  figures/instron/tst.png                                         |   Bin 126768 -> 106280 bytes
#  figures/workspace/x-y.emf                                       |   Bin 0 -> 28746164 bytes
#  figures/workspace/x-z.emf                                       |   Bin 0 -> 16656088 bytes
#  figures/workspace/z-x.png                                       |   Bin 378588 -> 0 bytes
#  matlab/brewermap.m                                              |   511 +
#  matlab/instron_plots.m                                          |     6 +-
#  matlab/training/data/2024_02_02_22_06_23/comp.mat               |   Bin 0 -> 212 bytes
#  matlab/training/data/2024_02_02_22_06_23/comp_delta.mat         |   Bin 0 -> 203 bytes
#  matlab/training/data/2024_02_02_22_06_23/comp_max.mat           |   Bin 0 -> 188 bytes
#  matlab/training/data/2024_02_02_22_06_23/delta_fast_repeat.csv  |  1000 ++
#  matlab/training/data/2024_02_02_22_06_23/delta_fast_repeat.mat  |   Bin 0 -> 69319 bytes
#  matlab/training/data/2024_02_02_22_06_23/home.mat               |   Bin 0 -> 184 bytes
#  matlab/training/data/2024_02_02_22_06_23/model_comp.mat         |   Bin 0 -> 201 bytes
#  matlab/training/data/2024_02_02_22_06_23/model_home.mat         |   Bin 0 -> 199 bytes
#  matlab/training/data/2024_02_02_22_10_00/comp.mat               |   Bin 0 -> 212 bytes
#  matlab/training/data/2024_02_02_22_10_00/comp_delta.mat         |   Bin 0 -> 203 bytes
#  matlab/training/data/2024_02_02_22_10_00/comp_max.mat           |   Bin 0 -> 188 bytes
#  matlab/training/data/2024_02_02_22_10_00/delta_fast_repeat.csv  |  1000 ++
#  matlab/training/data/2024_02_02_22_10_00/delta_fast_repeat.mat  |   Bin 0 -> 69319 bytes
#  matlab/training/data/2024_02_02_22_10_00/home.mat               |   Bin 0 -> 184 bytes
#  matlab/training/data/2024_02_02_22_10_00/model_comp.mat         |   Bin 0 -> 201 bytes
#  matlab/training/data/2024_02_02_22_10_00/model_home.mat         |   Bin 0 -> 199 bytes
#  matlab/training/data/2024_02_02_22_10_00/positions.csv          |  8440 +++++++++++++++++
#  matlab/training/data/2024_02_02_22_10_00/training_waypoints.mat |   Bin 0 -> 2695644 bytes
#  matlab/training/data/2024_02_03_14_18_15/comp.mat               |   Bin 0 -> 212 bytes
#  matlab/training/data/2024_02_03_14_18_15/comp_delta.mat         |   Bin 0 -> 203 bytes
#  matlab/training/data/2024_02_03_14_18_15/comp_max.mat           |   Bin 0 -> 188 bytes
#  matlab/training/data/2024_02_03_14_18_15/delta_fast_repeat.csv  |  1000 ++
#  matlab/training/data/2024_02_03_14_18_15/delta_fast_repeat.mat  |   Bin 0 -> 69057 bytes
#  matlab/training/data/2024_02_03_14_18_15/home.mat               |   Bin 0 -> 184 bytes
#  matlab/training/data/2024_02_03_14_18_15/model_comp.mat         |   Bin 0 -> 201 bytes
#  matlab/training/data/2024_02_03_14_18_15/model_home.mat         |   Bin 0 -> 199 bytes
#  matlab/training/data/2024_02_03_14_18_15/positions.csv          |     8 +
#  matlab/training/data/2024_02_03_14_18_15/training_waypoints.mat |   Bin 0 -> 2690508 bytes
#  matlab/training/data/2024_02_03_14_22_02/comp.mat               |   Bin 0 -> 212 bytes
#  matlab/training/data/2024_02_03_14_22_02/comp_delta.mat         |   Bin 0 -> 203 bytes
#  matlab/training/data/2024_02_03_14_22_02/comp_max.mat           |   Bin 0 -> 188 bytes
#  matlab/training/data/2024_02_03_14_22_02/delta_fast_repeat.csv  |  1000 ++
#  matlab/training/data/2024_02_03_14_22_02/delta_fast_repeat.mat  |   Bin 0 -> 69057 bytes
#  matlab/training/data/2024_02_03_14_22_02/home.mat               |   Bin 0 -> 184 bytes
#  matlab/training/data/2024_02_03_14_22_02/model_comp.mat         |   Bin 0 -> 201 bytes
#  matlab/training/data/2024_02_03_14_22_02/model_home.mat         |   Bin 0 -> 199 bytes
#  matlab/training/data/2024_02_03_14_22_02/positions.csv          | 13101 ++++++++++++++++++++++++++
#  matlab/training/data/2024_02_03_14_22_02/positions_trim.csv     |  8801 +++++++++++++++++
#  matlab/training/data/2024_02_03_14_22_02/training_waypoints.mat |   Bin 0 -> 2690508 bytes
#  .../data/2024_02_03_14_22_02/training_waypoints_matrix.mat      |   Bin 0 -> 2691634 bytes
#  matlab/training/kinematics.m                                    |    63 +-
#  matlab/training/kinematics/home.mat                             |   Bin 0 -> 200 bytes
#  matlab/training/picture_poses.asv                               |    58 +
#  matlab/training/picture_poses.m                                 |    19 +-
#  matlab/training/repeatability/2024_02_01_17_44_46/comp.mat      |   Bin 0 -> 214 bytes
#  .../training/repeatability/2024_02_01_17_44_46/comp_delta.mat   |   Bin 0 -> 203 bytes
#  matlab/training/repeatability/2024_02_01_17_44_46/comp_max.mat  |   Bin 0 -> 218 bytes
#  .../repeatability/2024_02_01_17_44_46/delta_fast_repeat.csv     |  1000 ++
#  .../repeatability/2024_02_01_17_44_46/delta_fast_repeat.mat     |   Bin 0 -> 68345 bytes
#  matlab/training/repeatability/2024_02_01_17_44_46/home.mat      |   Bin 0 -> 185 bytes
#  .../training/repeatability/2024_02_01_17_44_46/model_comp.mat   |   Bin 0 -> 201 bytes
#  .../training/repeatability/2024_02_01_17_44_46/model_home.mat   |   Bin 0 -> 199 bytes
#  matlab/training/repeatability/2024_02_01_17_44_46/positions.csv |   501 +
#  .../repeatability/2024_02_01_17_44_46/training_waypoints.mat    |   Bin 0 -> 2621754 bytes
#  .../2024_02_01_17_44_46}/training_waypoints_matrix.mat          |   Bin
#  matlab/training/repeatability/2024_02_02_10_19_41/comp.mat      |   Bin 0 -> 214 bytes
#  .../training/repeatability/2024_02_02_10_19_41/comp_delta.mat   |   Bin 0 -> 203 bytes
#  matlab/training/repeatability/2024_02_02_10_19_41/comp_max.mat  |   Bin 0 -> 218 bytes
#  .../repeatability/2024_02_02_10_19_41/delta_fast_repeat.csv     |  1000 ++
#  .../repeatability/2024_02_02_10_19_41/delta_fast_repeat.mat     |   Bin 0 -> 68345 bytes
#  matlab/training/repeatability/2024_02_02_10_19_41/home.mat      |   Bin 0 -> 185 bytes
#  .../training/repeatability/2024_02_02_10_19_41/model_comp.mat   |   Bin 0 -> 201 bytes
#  .../training/repeatability/2024_02_02_10_19_41/model_home.mat   |   Bin 0 -> 199 bytes
#  matlab/training/repeatability/2024_02_02_10_19_41/positions.csv |   501 +
#  .../repeatability/2024_02_02_10_19_41/training_waypoints.mat    |   Bin 0 -> 2621754 bytes
#  .../2024_02_02_10_19_41/training_waypoints_matrix.mat           |   Bin 0 -> 2617598 bytes
#  matlab/training/repeatability/2024_02_02_18_50_56/comp.mat      |   Bin 0 -> 212 bytes
#  .../training/repeatability/2024_02_02_18_50_56/comp_delta.mat   |   Bin 0 -> 203 bytes
#  matlab/training/repeatability/2024_02_02_18_50_56/comp_max.mat  |   Bin 0 -> 188 bytes
#  .../repeatability/2024_02_02_18_50_56/delta_fast_repeat.csv     |  1000 ++
#  .../repeatability/2024_02_02_18_50_56/delta_fast_repeat.mat     |   Bin 0 -> 69319 bytes
#  matlab/training/repeatability/2024_02_02_18_50_56/home.mat      |   Bin 0 -> 184 bytes
#  .../training/repeatability/2024_02_02_18_50_56/model_comp.mat   |   Bin 0 -> 201 bytes
#  .../training/repeatability/2024_02_02_18_50_56/model_home.mat   |   Bin 0 -> 199 bytes
#  matlab/training/repeatability/2024_02_02_18_50_56/positions.csv |   501 +
#  matlab/training/repeatability/2024_02_02_19_54_47/comp.mat      |   Bin 0 -> 212 bytes
#  .../training/repeatability/2024_02_02_19_54_47/comp_delta.mat   |   Bin 0 -> 203 bytes
#  matlab/training/repeatability/2024_02_02_19_54_47/comp_max.mat  |   Bin 0 -> 188 bytes
#  .../repeatability/2024_02_02_19_54_47/delta_fast_repeat.csv     |  1000 ++
#  .../repeatability/2024_02_02_19_54_47/delta_fast_repeat.mat     |   Bin 0 -> 69319 bytes
#  matlab/training/repeatability/2024_02_02_19_54_47/home.mat      |   Bin 0 -> 184 bytes
#  .../training/repeatability/2024_02_02_19_54_47/model_comp.mat   |   Bin 0 -> 201 bytes
#  .../training/repeatability/2024_02_02_19_54_47/model_home.mat   |   Bin 0 -> 199 bytes
#  matlab/training/repeatability/2024_02_02_19_54_47/positions.csv |   501 +
#  matlab/training/repeatability_sweep.asv                         |    94 +
#  matlab/training/repeatability_sweep.m                           |    19 +-
#  matlab/training/repeatability_test_loop.asv                     |   107 +
#  matlab/training/repeatability_test_loop.m                       |    12 +-
#  matlab/training/repetability_analysis.asv                       |   165 +-
#  matlab/training/repetability_analysis.m                         |   166 +-
#  matlab/training/reshape_trajectory.m                            |     4 +-
#  matlab/training/setup.asv                                       |    64 +
#  matlab/training/setup.m                                         |    12 +-
#  matlab/training/state/comp.mat                                  |   Bin 214 -> 212 bytes
#  matlab/training/state/comp_max.mat                              |   Bin 218 -> 188 bytes
#  matlab/training/state/home.mat                                  |   Bin 185 -> 184 bytes
#  matlab/training/training_sweep.m                                |    24 +-
#  matlab/training/training_test_loop.m                            |     1 -
#  matlab/training/trajectory/delta_fast_repeat.csv                |  2000 ++--
#  matlab/training/trajectory/delta_fast_repeat.mat                |   Bin 68362 -> 69057 bytes
#  matlab/training/trajectory/training_waypoints.mat               |   Bin 2621754 -> 2690508 bytes
#  matlab/workspace_plot.m                                         |    85 +
#  113 files changed, 42479 insertions(+), 1285 deletions(-)
#  create mode 100644 figures/workspace/x-y.emf
#  create mode 100644 figures/workspace/x-z.emf
#  delete mode 100644 figures/workspace/z-x.png
#  create mode 100644 matlab/brewermap.m
#  create mode 100644 matlab/training/data/2024_02_02_22_06_23/comp.mat
#  create mode 100644 matlab/training/data/2024_02_02_22_06_23/comp_delta.mat
#  create mode 100644 matlab/training/data/2024_02_02_22_06_23/comp_max.mat
#  create mode 100644 matlab/training/data/2024_02_02_22_06_23/delta_fast_repeat.csv
#  create mode 100644 matlab/training/data/2024_02_02_22_06_23/delta_fast_repeat.mat
#  create mode 100644 matlab/training/data/2024_02_02_22_06_23/home.mat
#  create mode 100644 matlab/training/data/2024_02_02_22_06_23/model_comp.mat
#  create mode 100644 matlab/training/data/2024_02_02_22_06_23/model_home.mat
#  create mode 100644 matlab/training/data/2024_02_02_22_10_00/comp.mat
#  create mode 100644 matlab/training/data/2024_02_02_22_10_00/comp_delta.mat
#  create mode 100644 matlab/training/data/2024_02_02_22_10_00/comp_max.mat
#  create mode 100644 matlab/training/data/2024_02_02_22_10_00/delta_fast_repeat.csv
#  create mode 100644 matlab/training/data/2024_02_02_22_10_00/delta_fast_repeat.mat
#  create mode 100644 matlab/training/data/2024_02_02_22_10_00/home.mat
#  create mode 100644 matlab/training/data/2024_02_02_22_10_00/model_comp.mat
#  create mode 100644 matlab/training/data/2024_02_02_22_10_00/model_home.mat
#  create mode 100644 matlab/training/data/2024_02_02_22_10_00/positions.csv
#  create mode 100644 matlab/training/data/2024_02_02_22_10_00/training_waypoints.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_18_15/comp.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_18_15/comp_delta.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_18_15/comp_max.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_18_15/delta_fast_repeat.csv
#  create mode 100644 matlab/training/data/2024_02_03_14_18_15/delta_fast_repeat.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_18_15/home.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_18_15/model_comp.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_18_15/model_home.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_18_15/positions.csv
#  create mode 100644 matlab/training/data/2024_02_03_14_18_15/training_waypoints.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_22_02/comp.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_22_02/comp_delta.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_22_02/comp_max.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_22_02/delta_fast_repeat.csv
#  create mode 100644 matlab/training/data/2024_02_03_14_22_02/delta_fast_repeat.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_22_02/home.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_22_02/model_comp.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_22_02/model_home.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_22_02/positions.csv
#  create mode 100644 matlab/training/data/2024_02_03_14_22_02/positions_trim.csv
#  create mode 100644 matlab/training/data/2024_02_03_14_22_02/training_waypoints.mat
#  create mode 100644 matlab/training/data/2024_02_03_14_22_02/training_waypoints_matrix.mat
#  create mode 100644 matlab/training/kinematics/home.mat
#  create mode 100644 matlab/training/picture_poses.asv
#  create mode 100644 matlab/training/repeatability/2024_02_01_17_44_46/comp.mat
#  create mode 100644 matlab/training/repeatability/2024_02_01_17_44_46/comp_delta.mat
#  create mode 100644 matlab/training/repeatability/2024_02_01_17_44_46/comp_max.mat
#  create mode 100644 matlab/training/repeatability/2024_02_01_17_44_46/delta_fast_repeat.csv
#  create mode 100644 matlab/training/repeatability/2024_02_01_17_44_46/delta_fast_repeat.mat
#  create mode 100644 matlab/training/repeatability/2024_02_01_17_44_46/home.mat
#  create mode 100644 matlab/training/repeatability/2024_02_01_17_44_46/model_comp.mat
#  create mode 100644 matlab/training/repeatability/2024_02_01_17_44_46/model_home.mat
#  create mode 100644 matlab/training/repeatability/2024_02_01_17_44_46/positions.csv
#  create mode 100644 matlab/training/repeatability/2024_02_01_17_44_46/training_waypoints.mat
#  rename matlab/training/{trajectory => repeatability/2024_02_01_17_44_46}/training_waypoints_matrix.mat (100%)
#  create mode 100644 matlab/training/repeatability/2024_02_02_10_19_41/comp.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_10_19_41/comp_delta.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_10_19_41/comp_max.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_10_19_41/delta_fast_repeat.csv
#  create mode 100644 matlab/training/repeatability/2024_02_02_10_19_41/delta_fast_repeat.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_10_19_41/home.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_10_19_41/model_comp.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_10_19_41/model_home.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_10_19_41/positions.csv
#  create mode 100644 matlab/training/repeatability/2024_02_02_10_19_41/training_waypoints.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_10_19_41/training_waypoints_matrix.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_18_50_56/comp.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_18_50_56/comp_delta.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_18_50_56/comp_max.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_18_50_56/delta_fast_repeat.csv
#  create mode 100644 matlab/training/repeatability/2024_02_02_18_50_56/delta_fast_repeat.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_18_50_56/home.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_18_50_56/model_comp.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_18_50_56/model_home.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_18_50_56/positions.csv
#  create mode 100644 matlab/training/repeatability/2024_02_02_19_54_47/comp.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_19_54_47/comp_delta.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_19_54_47/comp_max.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_19_54_47/delta_fast_repeat.csv
#  create mode 100644 matlab/training/repeatability/2024_02_02_19_54_47/delta_fast_repeat.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_19_54_47/home.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_19_54_47/model_comp.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_19_54_47/model_home.mat
#  create mode 100644 matlab/training/repeatability/2024_02_02_19_54_47/positions.csv
#  create mode 100644 matlab/training/repeatability_sweep.asv
#  create mode 100644 matlab/training/repeatability_test_loop.asv
#  create mode 100644 matlab/training/setup.asv
#  create mode 100644 matlab/workspace_plot.m
